# %% [markdown]
# # Two-layered model validation
#
# Validates the FEM solver against two-layer semi-analytical reference (eps_r = 4 / 9).

# %%
import sys, os

# ── locate master\ from examples\<name>\ (two levels up) ─────────────────
MASTER = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..', '..')) # need to fix
print(f"Master directory: {MASTER}")

sys.path.insert(0, os.path.join(MASTER, 'io'))
sys.path.insert(0, os.path.join(MASTER, 'io', 'inputs'))
sys.path.insert(0, os.path.join(MASTER, 'io', 'outputs'))

# inputs
from survey import GPRSurvey

# runner
from runner import ProjectPaths, run_tetgen, run_solver

# outputs
from fieldreader import AnalyticalLoader, ElfeLoader, load_elfe_batch
from postprocess import field_error, all_errors, error_stats
from visualize   import (ReceiverLinePlot, ReceiverLineErrorPlot,
                          ReceiverLineCombined, ErrorHistogramPlot)
# Out:
# Master directory: f:\Projects\EMGeoInversion\elfe3D_GPR

# %% [markdown]
# ---
# ## Paths

# %%
# ── set once per machine ───────────────────────────────────────────────────
paths = ProjectPaths(
    master_dir = MASTER,
    exec_rel   = r'elfe3D_GPR\elfe3d_gpr',
    use_wsl    = True,   # False if running from inside WSL
)

print('master   :', MASTER)
print('exec     :', paths.exec_path())
# Out:
# master   : f:\Projects\EMGeoInversion\elfe3D_GPR
# exec     : f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\elfe3d_gpr

# %% [markdown]
# ---
# ## 1 — Build and write inputs

# %%
f    = 100e6
wave = 3e8 / f     # 3.0 m in air;  lambda_2 = wave / sqrt(9) = 1.0 m in layer 2

BASE_DIR = os.path.join(MASTER, 'elfe3D_GPR')

survey = GPRSurvey.build(
    experiment_name = 'two_layered_earth',
    base_dir        = BASE_DIR,

    # Domain  (z goes down to just past second layer + PML)
    x_e = [-wave/10, 1 + wave/10],
    y_e = [-wave/10,     wave/10],
    z_e = [-1.0 - wave/10/3, wave/10],

    # Materials — air + 2 earth layers
    air_eps_r = 1.0,
    air_sigma = 1e-16,
    layer_thicknesses = [1.0,    wave/10/3],   # layer 1: 1 m,  layer 2: thin half-space
    layer_eps_r       = [4.0,    9.0],
    layer_sigma       = [1e-4,   1e-3],
    layer_mu_r        = [1.0,    1.0],
    layer_sigma_m     = [0.0,    0.0],

    # Source
    ricker_central_f    = f,
    num_points_per_range = 1,
    antenna_position    = [0.0, 0.0, 0.025],
    source_type         = 6,
    current_direction   = 1,
    num_segments        = 1,
    s_f                 = 250,
    bh_f                = 1.0,
    box_present         = False,
    box_x               = [-1 + 0.75, 1 + 0.375],

    # Receivers
    num_receivers_inline  = 48,
    num_receivers_endfire = 0,
    num_receivers_oblique = 0,

    # Solver
    solver_type      = 2,
    max_ref_steps    = 0,
    max_unknowns     = 5_000_000,
    accuracy_tol     = 3e-5,
    output_fields_vtk = 1,

    # PML
    num_pml_layers      = 1,
    pml_layer_thickness = wave/10,
    pml_type            = 'lin',
    pml_decay_type      = 1,

    least_samples_per_wavelength = 10,
)

survey.generate()
print('poly :', survey.io.poly_file)
# Out:
# odepths: [0.075, 0.0375, 0.025]
# Source antenna length: 0.0006 m
# Receiver antenna depth: -0.00015 m
# [0.0, -1.0]
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\in\GPR_model_two_layered_earth.poly
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\in\elfe3D_input.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\in\source.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\in\regionparameters.txt
# Input generation complete.
# poly : f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\in\GPR_model_two_layered_earth.poly

# %% [markdown]
# ---
# ## 2 — Mesh with TetGen

# %%
run_tetgen(paths, survey.io.poly_file)
# Out:
# ── TetGen ────────────────────────────────────────────
#    cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/elfe3D_GPR/in && /usr/bin/tetgen -pq1.2kAaen GPR_model_two_layered_earth.poly
#
# Opening GPR_model_two_layered_earth.poly.
# Delaunizing vertices...
# Delaunay seconds:  0.003053
# Creating surface mesh ...
# Surface mesh seconds:  0.001308
# Constrained Delaunay...
# Constrained Delaunay seconds:  0.001643
# Removing exterior tetrahedra ...
# Spreading region attributes.
# Exterior tets removal seconds:  0.000166
# Refining mesh...
# Refinement seconds:  0.814285
# Optimizing mesh...
# Optimization seconds:  0.044129
#
# Writing GPR_model_two_layered_earth.1.node.
# Writing GPR_model_two_layered_earth.1.ele.
# Writing GPR_model_two_layered_earth.1.face.
# Writing GPR_model_two_layered_earth.1.edge.
# Writing GPR_model_two_layered_earth.1.vtk.
# Writing GPR_model_two_layered_earth.1.neigh.
#
# Output seconds:  0.716101
# Total running seconds:  1.58088
#
# Statistics:
#
#   Input points: 242
#   Input facets: 127
#   Input segments: 369
#   Input holes: 0
#   Input regions: 45
#
#   Mesh points: 42657
#   Mesh tetrahedra: 255939
#   Mesh faces: 515294
#   Mesh edges: 302011
#   Mesh faces on facets: 31752
#   Mesh edges on segments: 1790
#   Steiner points inside domain: 27693
#   Steiner points on facets:  13301
#   Steiner points on segments:  1421
#
#
# ✓  done in 6.6s

# %% [markdown]
# ---
# ## 3 — Run solver

# %%
run_solver(paths,survey)
# Out:
# ── elfe3d_gpr ────────────────────────────────────────
#    wsl bash -c cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/elfe3D_GPR && /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/elfe3D_GPR/elfe3d_gpr
#
# ***************************************
# GPR forward modelling with elfe3D_GPR
# ***************************************
# Your forward problem is solved with
#  MUMPS
# *************************************
# Reading refinement information
# Your mesh will be refined
#  for             0 refinement steps
#  or until     5000000 unknowns
#  with error estim. method           3
#  with refinement strategy           1
# Your output files will be generated in: /out
# Field components in the domain will be in *.vtk file in: /in
# *************************************
# Reading model definitions
# Your input meshfile is called
#  in/GPR_model_two_layered_earth.
# Your mesh has
#        42657 Nodes
#       255939 Elements
#       302011 Edges (dof)
# *************************************
# Assembling connectivity arrays
# Calculating interpolation coefficients
# Obtaining model properties
# *************************************
# Source parameters:
#  CSTYPE           6
#  source-start coordinates:
#   -2.9999999999999997E-004   0.0000000000000000        2.5000000000000001E-002
#  source-end coordinates
#    2.9999999999999997E-004   0.0000000000000000        2.5000000000000001E-002
#  source moment               1.0000000000000000
# Segmented line source
# Number of source edges:
#            1
# Source edges and nodes:
#       213289
#          162         161
# *************************************
# Detecting surface edges
# Check if PEC present
# Check if PML present
# Detecting PML elements
# Number of PML elements:
#        48903
# Number of non-PML elements:
#       207036
# To Check, number of non-PML elements:
#       207036
# *************************************
# Checking elements for all receivers
# Receiver number and its Earth element:
#            1      105055
# Receiver number and its Earth element:
#            2      122361
# Receiver number and its Earth element:
#            3       63284
# Receiver number and its Earth element:
#            4       68195
# Receiver number and its Earth element:
#            5      103811
# Receiver number and its Earth element:
#            6       93795
# Receiver number and its Earth element:
#            7      103873
# Receiver number and its Earth element:
#            8      167631
# Receiver number and its Earth element:
#            9       20913
# Receiver number and its Earth element:
#           10      119943
# Receiver number and its Earth element:
#           11      126221
# Receiver number and its Earth element:
#           12      122024
# Receiver number and its Earth element:
#           13       80897
# Receiver number and its Earth element:
#           14       83029
# Receiver number and its Earth element:
#           15       36344
# Receiver number and its Earth element:
#           16       74116
# Receiver number and its Earth element:
#           17      118143
# Receiver number and its Earth element:
#           18       72119
# Receiver number and its Earth element:
#           19      158021
# Receiver number and its Earth element:
#           20       89784
# Receiver number and its Earth element:
#           21       84680
# Receiver number and its Earth element:
#           22        2496
# Receiver number and its Earth element:
#           23      124702
# Receiver number and its Earth element:
#           24       80840
# Receiver number and its Earth element:
#           25       73189
# Receiver number and its Earth element:
#           26       96153
# Receiver number and its Earth element:
#           27      113427
# Receiver number and its Earth element:
#           28        2606
# Receiver number and its Earth element:
#           29      102593
# Receiver number and its Earth element:
#           30       69338
# Receiver number and its Earth element:
#           31       78397
# Receiver number and its Earth element:
#           32      184556
# Receiver number and its Earth element:
#           33       59557
# Receiver number and its Earth element:
#           34       17846
# Receiver number and its Earth element:
#           35      128846
# Receiver number and its Earth element:
#           36       91693
# Receiver number and its Earth element:
#           37      149444
# Receiver number and its Earth element:
#           38       54318
# Receiver number and its Earth element:
#           39       98055
# Receiver number and its Earth element:
#           40      102194
# Receiver number and its Earth element:
#           41      106279
# Receiver number and its Earth element:
#           42       84817
# Receiver number and its Earth element:
#           43       92200
# Receiver number and its Earth element:
#           44      148511
# Receiver number and its Earth element:
#           45       91544
# Receiver number and its Earth element:
#           46      145870
# Receiver number and its Earth element:
#           47       73228
# Receiver number and its Earth element:
#           48      151226
# **********************************
#  Loop for frequency   100000000.00000000      [Hz]
# **********************************
# Evaluating PML complex stretching factors
#  Simple Reciprocal PML decay type
# Setting up system matrix
# Calculating global source vector
# Source length:
#    5.9999999999999995E-004
# Calculating RHS of dual problem
# Applying Dirichlet boundary condition
# Number of non-zero elements in Agcoo after applying BC:
#      8964167
# **********************************
# Solving primal and dual problems with MUMPS
#  OMP num threads          20
#
# Entering ZMUMPS 5.7.3 with JOB, N, NNZ =   6      302011        2531606
#       executing #MPI =      1 and #OMP =     20
#
#  =================================================
#  MUMPS compiled with option -Dmetis
#  MUMPS compiled with option -Dpord
#  MUMPS compiled with option -Dscotch
#  =================================================
# L D L^T Solver for general symmetric matrices
# Type of parallelism: Working host
#
#  ****** ANALYSIS STEP ********
#
#  Processing a graph of size:    302011
#  Average density of rows/columns =   15
#  Ordering based on SCOTCH
#  ELAPSED TIME SPENT IN SCOTCH reordering =      5.5745
#
# Leaving analysis phase with  ...
#  INFOG(1)                                       =               0
#  INFOG(2)                                       =               0
#  -- (20) Number of entries in factors (estim.)  =        90561137
#  --  (3) Real space for factors    (estimated)  =        95334038
#  --  (4) Integer space for factors (estimated)  =         3160672
#  --  (5) Maximum frontal size      (estimated)  =            2672
#  --  (6) Number of nodes in the tree            =           20589
#  -- (32) Type of analysis effectively used      =               1
#  --  (7) Ordering option effectively used       =               3
#  ICNTL (6) Maximum transversal option           =               0
#  ICNTL (7) Pivot order option                   =               3
#  ICNTL(12) Ordering symmetric indef. matrices   =               1
#  ICNTL(13) Parallelism/splitting of root node   =               0
#  ICNTL(14) Percentage of memory relaxation      =              20
#  ICNTL(15) Analysis by block effectively used   =               0
#  ICNTL(18) Distributed input matrix (on if >0)  =               0
#  ICNTL(32) Forward elimination during facto.    =               0
#  ICNTL(35) BLR activation                       =               0
#  ICNTL(48) Tree based multithreading (effective)=               1
#  ICNTL(58) Symbolic factorization option        =               2
#  Number of level 2 nodes                        =               0
#  Number of split nodes                          =               0
#  RINFOG(1) Operations during elimination (estim)= 8.295D+10
#
#  MEMORY ESTIMATIONS ...
#  Estimations with standard Full-Rank (FR) factorization:
#     Total space in MBytes, IC factorization      (INFOG(17)):            2083
#     Total space in MBytes,  OOC factorization    (INFOG(27)):             851
#
#  Elapsed time in analysis driver=       5.7452
#
#
# ****** FACTORIZATION STEP ********
#
#  GLOBAL STATISTICS PRIOR NUMERICAL FACTORIZATION ...
#  Number of working processes                =               1
#  ICNTL(22) Out-of-core option               =               0
#  ICNTL(35) BLR activation (eff. choice)     =               0
#  ICNTL(37) BLR CB compression (eff. choice) =               0
#  ICNTL(49) Compact workarray S (end facto.) =               0
#  ICNTL(14) Memory relaxation                =              20
#  INFOG(3) Real space for factors (estimated)=        95334038
#  INFOG(4) Integer space for factors (estim.)=         3160672
#  Maximum frontal size (estimated)           =            2672
#  Number of nodes in the tree                =           20589
#  ICNTL(23) Memory allowed (value on host)   =               0
#            Sum over all procs               =               0
#  Memory provided by user, sum of LWK_USER   =               0
#  Effective threshold for pivoting, CNTL(1)  =      0.1000D-01
#
#  Statistics on the scaling phase
#  Elapsed time for scaling                   =      0.1095
#  Max difference from 1 after scaling the entries for ONE-NORM (option 7/8)   = 0.21D+00
#
#  Effective size of S     (based on INFO(39))=             43733987
#  Elapsed time to reformat/distribute matrix =      0.0594
#
#
#  Allocated buffers
#  ------------------
#  Size of reception buffer in bytes ...... =       140000
#  Size of async. emission buffer (bytes).. =       140012
#  Small emission buffer (bytes) .......... =           20
#
#  ** Memory allocated, total in Mbytes           (INFOG(19)):        2083
#  ** Memory effectively used, total in Mbytes    (INFOG(22)):        1966
#
#  Flops under L0 layer                       =   2.953D+10
#  Elapsed time under L0                      =     25.4178
#
#  Elapsed time for factorization                     =    116.0929
#
# Leaving factorization with ...
#  RINFOG (2) Operations in node assembly             = 1.320D+08
#  ------ (3) Operations in node elimination          = 8.295D+10
#  ICNTL  (8) Scaling effectively used                =               7
#  INFOG  (9) Real space for factors                  =        95334038
#  INFOG (10) Integer space for factors               =         3160672
#  INFOG (11) Maximum front size                      =            2672
#  INFOG (29) Number of entries in factors            =        90561137
#  INFOG (13) Number of delayed pivots                =               0
#  Number of 2x2 pivots in type 1 nodes               =               0
#  Number of 2x2 pivots in type 2 nodes               =               0
#  RINFOG(19) Smallest pivot WITH perturbed pivots    = 2.060D-07
#  RINFOG(20) Smallest pivot WITHOUT perturbed pivots = 2.060D-07
#  RINFOG(21) Largest pivot in absolute value         = 2.935D+00
#  INFOG (24) Effective value of ICNTL(12)            =               1
#  INFOG (14) Number of memory compress               =               0
#
#  Elapsed time in factorization driver               =    116.2805
#
#
#  ****** SOLVE & CHECK STEP ********
#
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           2
#   --- (20)                                     =           0
#   --- (21)                                     =           0
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           1
#
#  ERROR ANALYSIS
#
#  RESIDUAL IS ............ (INF-NORM)        = 1.31D-07
#                        .. (2-NORM)          = 2.97D-07
#  RINFOG(4):NORM OF input  Matrix  (INF-NORM)= 5.43D+01
#  RINFOG(5):NORM OF Computed SOLUT (INF-NORM)= 1.52D+11
#  RINFOG(6):SCALED RESIDUAL ...... (INF-NORM)= 1.58D-20
#  RINFOG(7):COMPONENTWISE SCALED RESIDUAL(W1)= 6.53D-16
#  ------(8):---------------------------- (W2)= 4.13D-23
#  ** Space in MBYTES used for solve                        :      1789
#
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.058025
#  Time in solution step (fwd/bwd)  =       3.749112
#   .. Time in forward (fwd) step   =          3.071387
#   .. Time in backward (bwd) step  =          0.677721
#  Time to gather solution(cent.sol)=       0.099656
#  Time for distributed solution    =       0.000000
#
#  Elapsed time in solve driver=       4.0368
#
# Entering ZMUMPS 5.7.3 with JOB =  -2
#       executing #MPI =      1 and #OMP =     20
# **********************************
# No error estimation!
# ***********************************************************
# Writing Volumetric Field Distribution in Entire Domain Now
#  Domain fields are written into in/GPR_model_two_layered_earth.1.vtk
# Allocated variables were deallocated
# *************************************
# *************************************
# Modelling with elfe3D completed
# Output files are located in: /out
# *************************************
# *************************************
# CPU time to run elfe3D = 2567.240 seconds.
# Real time to run elfe3D =   174.533 seconds.
#
# ✓  done in 174.8s

# %% [markdown]
# ---
# ## 4 — Load results

# %%
result_txt = survey.io.output_dir / 'electric_fields_receiver_line.txt'
print('reading:', result_txt)

ef = ElfeLoader(
    filepath    = str(result_txt),
    label       = 'elfe3D  layered',
    num_endfire = 48,
).endfire()

print(f'r : {ef.r.min():.3f} - {ef.r.max():.3f} m   ({len(ef.r)} receivers)')
# Out:
# reading: f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\out_two_layered_earth\electric_fields_receiver_line.txt
# r : 0.100 - 1.000 m   (48 receivers)

# %% [markdown]
# ---
# ## 5 — Analytical reference

# %%
# Two-layer Evert reference  (eps_r = 4 / 9)
ANALYTICAL_DIR = r'F:\Projects\EMGeoInversion\elfe3D_GPR\data\data_semi_analytical'

semi_analytical = AnalyticalLoader(
    os.path.join(ANALYTICAL_DIR, 'Exx_single_freq_4_9_100MHz_NR.csv'),
    label='Semi-Analytical',
).endfire()

# %% [markdown]
# ---
# ## 6 — Comparison plot

# %%
ReceiverLinePlot([semi_analytical, ef]).plot(suptitle="Endfire - Two-layered Earth")

# %% [markdown]
# ## Error plot

# %%
ReceiverLineErrorPlot([ef], reference=semi_analytical).plot(suptitle="Errors vs Semi-Analytical - Two-Layered Earth")

# %% [markdown]
# ## Combined (fields + errors)

# %%
ReceiverLineCombined(ef, semi_analytical).plot(suptitle="Fields and errors - Two-layered Earth")

# %% [markdown]
# ## Error histogram

# %%
ErrorHistogramPlot([ef], reference=semi_analytical).plot(suptitle="Error distribution - Two-layered")

# %% [markdown]
# ## Printed error summary

# %%
qty_names = ['Amplitude', 'Phase', 'Real', 'Imaginary']
print(f'\n── {ef.label} ──')
for qi, name in enumerate(qty_names):
    err = field_error(semi_analytical, ef, qi)
    m, s, mx = error_stats(err)
    scale, unit = (100, '%') if qi != 1 else (1, 'rad')
    print(f'  {name:12s}:  mean={m*scale:.3f}{unit}  '
          f'std={s*scale:.3f}{unit}  max={mx*scale:.3f}{unit}')
# Out:
# ── elfe3D  layered ──
#   Amplitude   :  mean=1.688%  std=0.638%  max=2.716%
#   Phase       :  mean=-0.099rad  std=0.893rad  max=6.220rad
#   Real        :  mean=3.045%  std=1.630%  max=6.753%
#   Imaginary   :  mean=25.655%  std=96.992%  max=676.513%

# %% [markdown]
# ---
# ## 7 — PML thickness sweep
#
# Runs the same two-layer model for several PML thicknesses expressed as $\lambda_2 / n$ where $\lambda_2$ is the wavelength in the second layer. Builds a separate `GPRSurvey` for each case so every run is fully reproducible.
#
# **Run sections 7a-7c in order.  Once the runs are done, comment out 7b and jump straight to 7c to reload and replot.**

# %% [markdown]
# ### 7a — Set up sweep surveys

# %%
from visualize import ErrorStatPlot

# Sweep over PML thickness expressed as a fraction of lambda_2
# lambda_2 = wave / sqrt(eps_r_layer2) = 3.0 / 3.0 = 1.0 m
wave2  = 3e8 / (100e6 * 3.0)   # 1.0 m

denoms = [10, 12.5, 15, 17.5, 20, 22.5, 25]

# Each entry will be a separate survey with a different pml_layer_thickness
sweep_surveys = []
for d in denoms:
    s = GPRSurvey.build(
        experiment_name     = f'tl_pml_{str(d).replace(".", "p")}',
        base_dir            = os.path.join(MASTER, 'io', 'inputs'),
        x_e = [-wave/10, 1 + wave/10],
        y_e = [-wave/10,     wave/10],
        z_e = [-1.0 - wave/10/3, wave/10],
        air_eps_r = 1.0,  air_sigma = 1e-16,
        layer_thicknesses = [1.0, wave/10/3],
        layer_eps_r  = [4.0,  9.0],
        layer_sigma  = [1e-4, 1e-3],
        layer_mu_r   = [1.0,  1.0],
        layer_sigma_m= [0.0,  0.0],
        ricker_central_f    = f,
        num_points_per_range = 1,
        antenna_position    = [0.0, 0.0, 0.025],
        source_type=6, current_direction=1, num_segments=1,
        s_f=250, bh_f=1.0, box_present=False, box_x=[-1+0.75, 1+0.375],
        num_receivers_inline=48,
        solver_type=2, max_ref_steps=0, max_unknowns=5_000_000,
        accuracy_tol=3e-5, output_fields_vtk=1,
        num_pml_layers=1,
        pml_layer_thickness = wave2 / d,
        pml_type='lin', pml_decay_type=1,
        least_samples_per_wavelength=20,
    )
    sweep_surveys.append(s)

print(f'Prepared {len(sweep_surveys)} sweep cases')
for s in sweep_surveys:
    print(f'  {s.io.experiment_name}  pml = {s.pml.layer_thickness:.4f} m')
# Out:
# odepths: [0.0375, 0.01875, 0.0125]
# Source antenna length: 0.0003 m
# Receiver antenna depth: -7.5e-05 m
# odepths: [0.0375, 0.01875, 0.0125]
# Source antenna length: 0.0003 m
# Receiver antenna depth: -7.5e-05 m
# odepths: [0.0375, 0.01875, 0.0125]
# Source antenna length: 0.0003 m
# Receiver antenna depth: -7.5e-05 m
# odepths: [0.0375, 0.01875, 0.0125]
# Source antenna length: 0.0003 m
# Receiver antenna depth: -7.5e-05 m
# odepths: [0.0375, 0.01875, 0.0125]
# Source antenna length: 0.0003 m
# Receiver antenna depth: -7.5e-05 m
# odepths: [0.0375, 0.01875, 0.0125]
# Source antenna length: 0.0003 m
# Receiver antenna depth: -7.5e-05 m
# odepths: [0.0375, 0.01875, 0.0125]
# Source antenna length: 0.0003 m
# Receiver antenna depth: -7.5e-05 m
# Prepared 7 sweep cases
#   tl_pml_10  pml = 0.1000 m
#   tl_pml_12p5  pml = 0.0800 m
#   tl_pml_15  pml = 0.0667 m
#   tl_pml_17p5  pml = 0.0571 m
#   tl_pml_20  pml = 0.0500 m
#   tl_pml_22p5  pml = 0.0444 m
#   tl_pml_25  pml = 0.0400 m

# %% [markdown]
# ### 7b — Run each case  *(comment out once done)*

# %%
# ── write inputs, mesh and solve each sweep case ───────────────────────────
# Comment out once the runs are done; re-run only to regenerate.
for s in sweep_surveys:
    print(f'\n>>> {s.io.experiment_name}')
    s.generate()
    run_tetgen(paths, s.io.poly_file)
    run_solver(paths, s)
# Out:
# >>> tl_pml_10
# [0.0, -1.0]
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\GPR_model_tl_pml_10.poly
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\elfe3D_input.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\source.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\regionparameters.txt
# Input generation complete.
# ── TetGen ────────────────────────────────────────────
#    cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/io/inputs/in && /usr/bin/tetgen -pq1.2kAaen GPR_model_tl_pml_10.poly
#
# Opening GPR_model_tl_pml_10.poly.
# Delaunizing vertices...
# Delaunay seconds:  0.005195
# Creating surface mesh ...
# Surface mesh seconds:  0.001693
# Constrained Delaunay...
# Constrained Delaunay seconds:  0.0014
# Removing exterior tetrahedra ...
# Spreading region attributes.
# Exterior tets removal seconds:  0.000191
# Refining mesh...
# Refinement seconds:  1.61845
# Optimizing mesh...
# Optimization seconds:  0.069829
#
# Writing GPR_model_tl_pml_10.1.node.
# Writing GPR_model_tl_pml_10.1.ele.
# Writing GPR_model_tl_pml_10.1.face.
# Writing GPR_model_tl_pml_10.1.edge.
# Writing GPR_model_tl_pml_10.1.vtk.
# Writing GPR_model_tl_pml_10.1.neigh.
#
# Output seconds:  1.44565
# Total running seconds:  3.14251
#
# Statistics:
#
#   Input points: 242
#   Input facets: 127
#   Input segments: 369
#   Input holes: 0
#   Input regions: 45
#
#   Mesh points: 75462
#   Mesh tetrahedra: 449007
#   Mesh faces: 905591
#   Mesh edges: 532045
#   Mesh faces on facets: 58031
#   Mesh edges on segments: 2760
#   Steiner points inside domain: 47895
#   Steiner points on facets:  24934
#   Steiner points on segments:  2391
#
#
# ✓  done in 8.7s
# ── elfe3d_gpr ────────────────────────────────────────
#    wsl bash -c cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/io/inputs && /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/elfe3D_GPR/elfe3d_gpr
#
# ***************************************
# GPR forward modelling with elfe3D_GPR
# ***************************************
# Your forward problem is solved with
#  MUMPS
# *************************************
# Reading refinement information
# Your mesh will be refined
#  for             0 refinement steps
#  or until     5000000 unknowns
#  with error estim. method           3
#  with refinement strategy           1
# Your output files will be generated in: /out
# Field components in the domain will be in *.vtk file in: /in
# *************************************
# Reading model definitions
# Your input meshfile is called
#  in/GPR_model_tl_pml_10.
# Your mesh has
#        75462 Nodes
#       449007 Elements
#       532045 Edges (dof)
# *************************************
# Assembling connectivity arrays
# Calculating interpolation coefficients
# Obtaining model properties
# *************************************
# Source parameters:
#  CSTYPE           6
#  source-start coordinates:
#   -1.4999999999999999E-004   0.0000000000000000        2.5000000000000001E-002
#  source-end coordinates
#    1.4999999999999999E-004   0.0000000000000000        2.5000000000000001E-002
#  source moment               1.0000000000000000
# Segmented line source
# Number of source edges:
#            1
# Source edges and nodes:
#        21420
#          162         161
# *************************************
# Detecting surface edges
# Check if PEC present
# Check if PML present
# Detecting PML elements
# Number of PML elements:
#        64015
# Number of non-PML elements:
#       384992
# To Check, number of non-PML elements:
#       384992
# *************************************
# Checking elements for all receivers
# Receiver number and its Earth element:
#            1      169261
# Receiver number and its Earth element:
#            2      148612
# Receiver number and its Earth element:
#            3      193177
# Receiver number and its Earth element:
#            4      129887
# Receiver number and its Earth element:
#            5      166363
# Receiver number and its Earth element:
#            6      233414
# Receiver number and its Earth element:
#            7       51148
# Receiver number and its Earth element:
#            8      211958
# Receiver number and its Earth element:
#            9      191122
# Receiver number and its Earth element:
#           10       29819
# Receiver number and its Earth element:
#           11      202840
# Receiver number and its Earth element:
#           12      252169
# Receiver number and its Earth element:
#           13      254369
# Receiver number and its Earth element:
#           14       76417
# Receiver number and its Earth element:
#           15      242551
# Receiver number and its Earth element:
#           16      215285
# Receiver number and its Earth element:
#           17      340007
# Receiver number and its Earth element:
#           18      216935
# Receiver number and its Earth element:
#           19      214792
# Receiver number and its Earth element:
#           20       21669
# Receiver number and its Earth element:
#           21      146551
# Receiver number and its Earth element:
#           22      245469
# Receiver number and its Earth element:
#           23      225256
# Receiver number and its Earth element:
#           24      216307
# Receiver number and its Earth element:
#           25      200783
# Receiver number and its Earth element:
#           26      158661
# Receiver number and its Earth element:
#           27      196816
# Receiver number and its Earth element:
#           28      277684
# Receiver number and its Earth element:
#           29      268689
# Receiver number and its Earth element:
#           30      227623
# Receiver number and its Earth element:
#           31      165130
# Receiver number and its Earth element:
#           32      270582
# Receiver number and its Earth element:
#           33      272717
# Receiver number and its Earth element:
#           34      234953
# Receiver number and its Earth element:
#           35      138668
# Receiver number and its Earth element:
#           36      205916
# Receiver number and its Earth element:
#           37      174104
# Receiver number and its Earth element:
#           38       31505
# Receiver number and its Earth element:
#           39      251731
# Receiver number and its Earth element:
#           40      260774
# Receiver number and its Earth element:
#           41      208553
# Receiver number and its Earth element:
#           42      260845
# Receiver number and its Earth element:
#           43      227812
# Receiver number and its Earth element:
#           44      240913
# Receiver number and its Earth element:
#           45      190013
# Receiver number and its Earth element:
#           46      110951
# Receiver number and its Earth element:
#           47      121959
# Receiver number and its Earth element:
#           48      173938
# **********************************
#  Loop for frequency   100000000.00000000      [Hz]
# **********************************
# Evaluating PML complex stretching factors
#  Simple Reciprocal PML decay type
# Setting up system matrix
# Calculating global source vector
# Source length:
#    2.9999999999999997E-004
# Calculating RHS of dual problem
# Applying Dirichlet boundary condition
# Number of non-zero elements in Agcoo after applying BC:
#     15615547
# **********************************
# Solving primal and dual problems with MUMPS
#  OMP num threads          20
#
# Entering ZMUMPS 5.7.3 with JOB, N, NNZ =   6      532045        4412081
#       executing #MPI =      1 and #OMP =     20
#
#  =================================================
#  MUMPS compiled with option -Dmetis
#  MUMPS compiled with option -Dpord
#  MUMPS compiled with option -Dscotch
#  =================================================
# L D L^T Solver for general symmetric matrices
# Type of parallelism: Working host
#
#  ****** ANALYSIS STEP ********
#
#  Processing a graph of size:    532045
#  Average density of rows/columns =   15
#  Ordering based on SCOTCH
#  ELAPSED TIME SPENT IN SCOTCH reordering =     10.4647
#
# Leaving analysis phase with  ...
#  INFOG(1)                                       =               0
#  INFOG(2)                                       =               0
#  -- (20) Number of entries in factors (estim.)  =       170182401
#  --  (3) Real space for factors    (estimated)  =       178638057
#  --  (4) Integer space for factors (estimated)  =         5697816
#  --  (5) Maximum frontal size      (estimated)  =            3514
#  --  (6) Number of nodes in the tree            =           40889
#  -- (32) Type of analysis effectively used      =               1
#  --  (7) Ordering option effectively used       =               3
#  ICNTL (6) Maximum transversal option           =               0
#  ICNTL (7) Pivot order option                   =               3
#  ICNTL(12) Ordering symmetric indef. matrices   =               1
#  ICNTL(13) Parallelism/splitting of root node   =               0
#  ICNTL(14) Percentage of memory relaxation      =              20
#  ICNTL(15) Analysis by block effectively used   =               0
#  ICNTL(18) Distributed input matrix (on if >0)  =               0
#  ICNTL(32) Forward elimination during facto.    =               0
#  ICNTL(35) BLR activation                       =               0
#  ICNTL(48) Tree based multithreading (effective)=               1
#  ICNTL(58) Symbolic factorization option        =               2
#  Number of level 2 nodes                        =               0
#  Number of split nodes                          =               0
#  RINFOG(1) Operations during elimination (estim)= 1.926D+11
#
#  MEMORY ESTIMATIONS ...
#  Estimations with standard Full-Rank (FR) factorization:
#     Total space in MBytes, IC factorization      (INFOG(17)):            3820
#     Total space in MBytes,  OOC factorization    (INFOG(27)):            1671
#
#  Elapsed time in analysis driver=      10.7209
#
#
# ****** FACTORIZATION STEP ********
#
#  GLOBAL STATISTICS PRIOR NUMERICAL FACTORIZATION ...
#  Number of working processes                =               1
#  ICNTL(22) Out-of-core option               =               0
#  ICNTL(35) BLR activation (eff. choice)     =               0
#  ICNTL(37) BLR CB compression (eff. choice) =               0
#  ICNTL(49) Compact workarray S (end facto.) =               0
#  ICNTL(14) Memory relaxation                =              20
#  INFOG(3) Real space for factors (estimated)=       178638057
#  INFOG(4) Integer space for factors (estim.)=         5697816
#  Maximum frontal size (estimated)           =            3514
#  Number of nodes in the tree                =           40889
#  ICNTL(23) Memory allowed (value on host)   =               0
#            Sum over all procs               =               0
#  Memory provided by user, sum of LWK_USER   =               0
#  Effective threshold for pivoting, CNTL(1)  =      0.1000D-01
#
#  Statistics on the scaling phase
#  Elapsed time for scaling                   =      0.1730
#  Max difference from 1 after scaling the entries for ONE-NORM (option 7/8)   = 0.28D+00
#
#  Effective size of S     (based on INFO(39))=             70260331
#  Elapsed time to reformat/distribute matrix =      0.0859
#
#
#  Allocated buffers
#  ------------------
#  Size of reception buffer in bytes ...... =       140000
#  Size of async. emission buffer (bytes).. =       158214
#  Small emission buffer (bytes) .......... =           20
#
#  ** Memory allocated, total in Mbytes           (INFOG(19)):        3820
#  ** Memory effectively used, total in Mbytes    (INFOG(22)):        3633
#
#  Flops under L0 layer                       =   7.843D+10
#  Elapsed time under L0                      =     39.3968
#
#  Elapsed time for factorization                     =    153.8380
#
# Leaving factorization with ...
#  RINFOG (2) Operations in node assembly             = 2.652D+08
#  ------ (3) Operations in node elimination          = 1.926D+11
#  ICNTL  (8) Scaling effectively used                =               7
#  INFOG  (9) Real space for factors                  =       178638057
#  INFOG (10) Integer space for factors               =         5697816
#  INFOG (11) Maximum front size                      =            3514
#  INFOG (29) Number of entries in factors            =       170182401
#  INFOG (13) Number of delayed pivots                =               0
#  Number of 2x2 pivots in type 1 nodes               =               1
#  Number of 2x2 pivots in type 2 nodes               =               0
#  RINFOG(19) Smallest pivot WITH perturbed pivots    = 6.330D-08
#  RINFOG(20) Smallest pivot WITHOUT perturbed pivots = 6.330D-08
#  RINFOG(21) Largest pivot in absolute value         = 3.418D+00
#  INFOG (24) Effective value of ICNTL(12)            =               1
#  INFOG (14) Number of memory compress               =               0
#
#  Elapsed time in factorization driver               =    154.1168
#
#
#  ****** SOLVE & CHECK STEP ********
#
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           2
#   --- (20)                                     =           0
#   --- (21)                                     =           0
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           1
#
#  ERROR ANALYSIS
#
#  RESIDUAL IS ............ (INF-NORM)        = 9.50D-07
#                        .. (2-NORM)          = 2.28D-06
#  RINFOG(4):NORM OF input  Matrix  (INF-NORM)= 6.60D+01
#  RINFOG(5):NORM OF Computed SOLUT (INF-NORM)= 1.57D+12
#  RINFOG(6):SCALED RESIDUAL ...... (INF-NORM)= 9.16D-21
#  RINFOG(7):COMPONENTWISE SCALED RESIDUAL(W1)= 1.78D-15
#  ------(8):---------------------------- (W2)= 5.79D-23
#  ** Space in MBYTES used for solve                        :      3301
#
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.088088
#  Time in solution step (fwd/bwd)  =       6.323606
#   .. Time in forward (fwd) step   =          3.537033
#   .. Time in backward (bwd) step  =          2.786551
#  Time to gather solution(cent.sol)=       0.080189
#  Time for distributed solution    =       0.000000
#
#  Elapsed time in solve driver=       6.7477
#
# Entering ZMUMPS 5.7.3 with JOB =  -2
#       executing #MPI =      1 and #OMP =     20
# **********************************
# No error estimation!
# ***********************************************************
# Writing Volumetric Field Distribution in Entire Domain Now
#  Domain fields are written into in/GPR_model_tl_pml_10.1.vtk
# Allocated variables were deallocated
# *************************************
# *************************************
# Modelling with elfe3D completed
# Output files are located in: /out
# *************************************
# *************************************
# CPU time to run elfe3D = 3891.380 seconds.
# Real time to run elfe3D =   277.892 seconds.
#
# ✓  done in 278.2s
#
# >>> tl_pml_12p5
# [0.0, -1.0]
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\GPR_model_tl_pml_12p5.poly
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\elfe3D_input.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\source.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\regionparameters.txt
# Input generation complete.
# ── TetGen ────────────────────────────────────────────
#    cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/io/inputs/in && /usr/bin/tetgen -pq1.2kAaen GPR_model_tl_pml_12p5.poly
#
# Opening GPR_model_tl_pml_12p5.poly.
# Delaunizing vertices...
# Delaunay seconds:  0.00276
# Creating surface mesh ...
# Surface mesh seconds:  0.001198
# Constrained Delaunay...
# Constrained Delaunay seconds:  0.001741
# Removing exterior tetrahedra ...
# Spreading region attributes.
# Exterior tets removal seconds:  0.0002
# Refining mesh...
# Refinement seconds:  1.5552
# Optimizing mesh...
# Optimization seconds:  0.071989
#
# Writing GPR_model_tl_pml_12p5.1.node.
# Writing GPR_model_tl_pml_12p5.1.ele.
# Writing GPR_model_tl_pml_12p5.1.face.
# Writing GPR_model_tl_pml_12p5.1.edge.
# Writing GPR_model_tl_pml_12p5.1.vtk.
# Writing GPR_model_tl_pml_12p5.1.neigh.
#
# Output seconds:  1.28621
# Total running seconds:  2.91941
#
# Statistics:
#
#   Input points: 242
#   Input facets: 127
#   Input segments: 369
#   Input holes: 0
#   Input regions: 45
#
#   Mesh points: 71618
#   Mesh tetrahedra: 426946
#   Mesh faces: 860809
#   Mesh edges: 505480
#   Mesh faces on facets: 54762
#   Mesh edges on segments: 2596
#   Steiner points inside domain: 45620
#   Steiner points on facets:  23529
#   Steiner points on segments:  2227
#
#
# ✓  done in 8.0s
# ── elfe3d_gpr ────────────────────────────────────────
#    wsl bash -c cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/io/inputs && /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/elfe3D_GPR/elfe3d_gpr
#
# ***************************************
# GPR forward modelling with elfe3D_GPR
# ***************************************
# Your forward problem is solved with
#  MUMPS
# *************************************
# Reading refinement information
# Your mesh will be refined
#  for             0 refinement steps
#  or until     5000000 unknowns
#  with error estim. method           3
#  with refinement strategy           1
# Your output files will be generated in: /out
# Field components in the domain will be in *.vtk file in: /in
# *************************************
# Reading model definitions
# Your input meshfile is called
#  in/GPR_model_tl_pml_12p5.
# Your mesh has
#        71618 Nodes
#       426946 Elements
#       505480 Edges (dof)
# *************************************
# Assembling connectivity arrays
# Calculating interpolation coefficients
# Obtaining model properties
# *************************************
# Source parameters:
#  CSTYPE           6
#  source-start coordinates:
#   -1.4999999999999999E-004   0.0000000000000000        2.5000000000000001E-002
#  source-end coordinates
#    1.4999999999999999E-004   0.0000000000000000        2.5000000000000001E-002
#  source moment               1.0000000000000000
# Segmented line source
# Number of source edges:
#            1
# Source edges and nodes:
#       428186
#          162         161
# *************************************
# Detecting surface edges
# Check if PEC present
# Check if PML present
# Detecting PML elements
# Number of PML elements:
#        67569
# Number of non-PML elements:
#       359377
# To Check, number of non-PML elements:
#       359377
# *************************************
# Checking elements for all receivers
# Receiver number and its Earth element:
#            1      158032
# Receiver number and its Earth element:
#            2      245669
# Receiver number and its Earth element:
#            3      309254
# Receiver number and its Earth element:
#            4      128691
# Receiver number and its Earth element:
#            5      161028
# Receiver number and its Earth element:
#            6      205135
# Receiver number and its Earth element:
#            7      360367
# Receiver number and its Earth element:
#            8      169764
# Receiver number and its Earth element:
#            9      176233
# Receiver number and its Earth element:
#           10       27506
# Receiver number and its Earth element:
#           11      279363
# Receiver number and its Earth element:
#           12      205511
# Receiver number and its Earth element:
#           13      197138
# Receiver number and its Earth element:
#           14      204173
# Receiver number and its Earth element:
#           15      313974
# Receiver number and its Earth element:
#           16      134132
# Receiver number and its Earth element:
#           17      214364
# Receiver number and its Earth element:
#           18      174855
# Receiver number and its Earth element:
#           19      176115
# Receiver number and its Earth element:
#           20      158962
# Receiver number and its Earth element:
#           21      167379
# Receiver number and its Earth element:
#           22      260828
# Receiver number and its Earth element:
#           23       38976
# Receiver number and its Earth element:
#           24       88188
# Receiver number and its Earth element:
#           25      225374
# Receiver number and its Earth element:
#           26      173465
# Receiver number and its Earth element:
#           27      186879
# Receiver number and its Earth element:
#           28      184657
# Receiver number and its Earth element:
#           29      147460
# Receiver number and its Earth element:
#           30      293343
# Receiver number and its Earth element:
#           31      171417
# Receiver number and its Earth element:
#           32      152902
# Receiver number and its Earth element:
#           33      103010
# Receiver number and its Earth element:
#           34      236762
# Receiver number and its Earth element:
#           35       91283
# Receiver number and its Earth element:
#           36      217527
# Receiver number and its Earth element:
#           37      158775
# Receiver number and its Earth element:
#           38      176462
# Receiver number and its Earth element:
#           39       62281
# Receiver number and its Earth element:
#           40      165325
# Receiver number and its Earth element:
#           41      178334
# Receiver number and its Earth element:
#           42      240189
# Receiver number and its Earth element:
#           43      102269
# Receiver number and its Earth element:
#           44      157746
# Receiver number and its Earth element:
#           45      191466
# Receiver number and its Earth element:
#           46      257727
# Receiver number and its Earth element:
#           47      174373
# Receiver number and its Earth element:
#           48      300013
# **********************************
#  Loop for frequency   100000000.00000000      [Hz]
# **********************************
# Evaluating PML complex stretching factors
#  Simple Reciprocal PML decay type
# Setting up system matrix
# Calculating global source vector
# Source length:
#    2.9999999999999997E-004
# Calculating RHS of dual problem
# Applying Dirichlet boundary condition
# Number of non-zero elements in Agcoo after applying BC:
#     14866683
# **********************************
# Solving primal and dual problems with MUMPS
#  OMP num threads          20
#
# Entering ZMUMPS 5.7.3 with JOB, N, NNZ =   6      505480        4200137
#       executing #MPI =      1 and #OMP =     20
#
#  =================================================
#  MUMPS compiled with option -Dmetis
#  MUMPS compiled with option -Dpord
#  MUMPS compiled with option -Dscotch
#  =================================================
# L D L^T Solver for general symmetric matrices
# Type of parallelism: Working host
#
#  ****** ANALYSIS STEP ********
#
#  Processing a graph of size:    505480
#  Average density of rows/columns =   15
#  Ordering based on SCOTCH
#  ELAPSED TIME SPENT IN SCOTCH reordering =      9.9324
#
# Leaving analysis phase with  ...
#  INFOG(1)                                       =               0
#  INFOG(2)                                       =               0
#  -- (20) Number of entries in factors (estim.)  =       155463414
#  --  (3) Real space for factors    (estimated)  =       163405177
#  --  (4) Integer space for factors (estimated)  =         5389126
#  --  (5) Maximum frontal size      (estimated)  =            3127
#  --  (6) Number of nodes in the tree            =           38090
#  -- (32) Type of analysis effectively used      =               1
#  --  (7) Ordering option effectively used       =               3
#  ICNTL (6) Maximum transversal option           =               0
#  ICNTL (7) Pivot order option                   =               3
#  ICNTL(12) Ordering symmetric indef. matrices   =               1
#  ICNTL(13) Parallelism/splitting of root node   =               0
#  ICNTL(14) Percentage of memory relaxation      =              20
#  ICNTL(15) Analysis by block effectively used   =               0
#  ICNTL(18) Distributed input matrix (on if >0)  =               0
#  ICNTL(32) Forward elimination during facto.    =               0
#  ICNTL(35) BLR activation                       =               0
#  ICNTL(48) Tree based multithreading (effective)=               1
#  ICNTL(58) Symbolic factorization option        =               2
#  Number of level 2 nodes                        =               0
#  Number of split nodes                          =               0
#  RINFOG(1) Operations during elimination (estim)= 1.607D+11
#
#  MEMORY ESTIMATIONS ...
#  Estimations with standard Full-Rank (FR) factorization:
#     Total space in MBytes, IC factorization      (INFOG(17)):            3560
#     Total space in MBytes,  OOC factorization    (INFOG(27)):            1588
#
#  Elapsed time in analysis driver=      10.1678
#
#
# ****** FACTORIZATION STEP ********
#
#  GLOBAL STATISTICS PRIOR NUMERICAL FACTORIZATION ...
#  Number of working processes                =               1
#  ICNTL(22) Out-of-core option               =               0
#  ICNTL(35) BLR activation (eff. choice)     =               0
#  ICNTL(37) BLR CB compression (eff. choice) =               0
#  ICNTL(49) Compact workarray S (end facto.) =               0
#  ICNTL(14) Memory relaxation                =              20
#  INFOG(3) Real space for factors (estimated)=       163405177
#  INFOG(4) Integer space for factors (estim.)=         5389126
#  Maximum frontal size (estimated)           =            3127
#  Number of nodes in the tree                =           38090
#  ICNTL(23) Memory allowed (value on host)   =               0
#            Sum over all procs               =               0
#  Memory provided by user, sum of LWK_USER   =               0
#  Effective threshold for pivoting, CNTL(1)  =      0.1000D-01
#
#  Statistics on the scaling phase
#  Elapsed time for scaling                   =      0.1713
#  Max difference from 1 after scaling the entries for ONE-NORM (option 7/8)   = 0.28D+00
#
#  Effective size of S     (based on INFO(39))=             59765142
#  Elapsed time to reformat/distribute matrix =      0.0931
#
#
#  Allocated buffers
#  ------------------
#  Size of reception buffer in bytes ...... =       140000
#  Size of async. emission buffer (bytes).. =       140789
#  Small emission buffer (bytes) .......... =           20
#
#  ** Memory allocated, total in Mbytes           (INFOG(19)):        3534
#  ** Memory effectively used, total in Mbytes    (INFOG(22)):        3303
#
#  Flops under L0 layer                       =   7.136D+10
#  Elapsed time under L0                      =     53.4388
#
#  Elapsed time for factorization                     =    157.8010
#
# Leaving factorization with ...
#  RINFOG (2) Operations in node assembly             = 2.386D+08
#  ------ (3) Operations in node elimination          = 1.607D+11
#  ICNTL  (8) Scaling effectively used                =               7
#  INFOG  (9) Real space for factors                  =       163405177
#  INFOG (10) Integer space for factors               =         5389126
#  INFOG (11) Maximum front size                      =            3127
#  INFOG (29) Number of entries in factors            =       155463414
#  INFOG (13) Number of delayed pivots                =               0
#  Number of 2x2 pivots in type 1 nodes               =               1
#  Number of 2x2 pivots in type 2 nodes               =               0
#  RINFOG(19) Smallest pivot WITH perturbed pivots    = 7.000D-08
#  RINFOG(20) Smallest pivot WITHOUT perturbed pivots = 7.000D-08
#  RINFOG(21) Largest pivot in absolute value         = 1.863D+00
#  INFOG (24) Effective value of ICNTL(12)            =               1
#  INFOG (14) Number of memory compress               =               0
#
#  Elapsed time in factorization driver               =    158.1117
#
#
#  ****** SOLVE & CHECK STEP ********
#
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           2
#   --- (20)                                     =           0
#   --- (21)                                     =           0
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           1
#
#  ERROR ANALYSIS
#
#  RESIDUAL IS ............ (INF-NORM)        = 6.44D-07
#                        .. (2-NORM)          = 1.37D-06
#  RINFOG(4):NORM OF input  Matrix  (INF-NORM)= 8.25D+01
#  RINFOG(5):NORM OF Computed SOLUT (INF-NORM)= 1.26D+12
#  RINFOG(6):SCALED RESIDUAL ...... (INF-NORM)= 6.17D-21
#  RINFOG(7):COMPONENTWISE SCALED RESIDUAL(W1)= 4.73D-16
#  ------(8):---------------------------- (W2)= 3.81D-23
#  ** Space in MBYTES used for solve                        :      3007
#
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.134948
#  Time in solution step (fwd/bwd)  =       4.337699
#   .. Time in forward (fwd) step   =          3.342196
#   .. Time in backward (bwd) step  =          0.995498
#  Time to gather solution(cent.sol)=       0.060155
#  Time for distributed solution    =       0.000000
#
#  Elapsed time in solve driver=       4.7662
#
# Entering ZMUMPS 5.7.3 with JOB =  -2
#       executing #MPI =      1 and #OMP =     20
# **********************************
# No error estimation!
# ***********************************************************
# Writing Volumetric Field Distribution in Entire Domain Now
#  Domain fields are written into in/GPR_model_tl_pml_12p5.1.vtk
# Allocated variables were deallocated
# *************************************
# *************************************
# Modelling with elfe3D completed
# Output files are located in: /out
# *************************************
# *************************************
# CPU time to run elfe3D = 3901.646 seconds.
# Real time to run elfe3D =   277.359 seconds.
#
# ✓  done in 277.6s
#
# >>> tl_pml_15
# [0.0, -1.0]
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\GPR_model_tl_pml_15.poly
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\elfe3D_input.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\source.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\regionparameters.txt
# Input generation complete.
# ── TetGen ────────────────────────────────────────────
#    cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/io/inputs/in && /usr/bin/tetgen -pq1.2kAaen GPR_model_tl_pml_15.poly
#
# Opening GPR_model_tl_pml_15.poly.
# Delaunizing vertices...
# Delaunay seconds:  0.002655
# Creating surface mesh ...
# Surface mesh seconds:  0.000956
# Constrained Delaunay...
# Constrained Delaunay seconds:  0.00153
# Removing exterior tetrahedra ...
# Spreading region attributes.
# Exterior tets removal seconds:  0.000148
# Refining mesh...
# Refinement seconds:  1.35824
# Optimizing mesh...
# Optimization seconds:  0.062502
#
# Writing GPR_model_tl_pml_15.1.node.
# Writing GPR_model_tl_pml_15.1.ele.
# Writing GPR_model_tl_pml_15.1.face.
# Writing GPR_model_tl_pml_15.1.edge.
# Writing GPR_model_tl_pml_15.1.vtk.
# Writing GPR_model_tl_pml_15.1.neigh.
#
# Output seconds:  1.42113
# Total running seconds:  2.84725
#
# Statistics:
#
#   Input points: 242
#   Input facets: 127
#   Input segments: 369
#   Input holes: 0
#   Input regions: 45
#
#   Mesh points: 69195
#   Mesh tetrahedra: 412002
#   Mesh faces: 830916
#   Mesh edges: 488108
#   Mesh faces on facets: 53872
#   Mesh edges on segments: 2667
#   Steiner points inside domain: 43672
#   Steiner points on facets:  22983
#   Steiner points on segments:  2298
#
#
# ✓  done in 8.3s
# ── elfe3d_gpr ────────────────────────────────────────
#    wsl bash -c cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/io/inputs && /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/elfe3D_GPR/elfe3d_gpr
#
# ***************************************
# GPR forward modelling with elfe3D_GPR
# ***************************************
# Your forward problem is solved with
#  MUMPS
# *************************************
# Reading refinement information
# Your mesh will be refined
#  for             0 refinement steps
#  or until     5000000 unknowns
#  with error estim. method           3
#  with refinement strategy           1
# Your output files will be generated in: /out
# Field components in the domain will be in *.vtk file in: /in
# *************************************
# Reading model definitions
# Your input meshfile is called
#  in/GPR_model_tl_pml_15.
# Your mesh has
#        69195 Nodes
#       412002 Elements
#       488108 Edges (dof)
# *************************************
# Assembling connectivity arrays
# Calculating interpolation coefficients
# Obtaining model properties
# *************************************
# Source parameters:
#  CSTYPE           6
#  source-start coordinates:
#   -1.4999999999999999E-004   0.0000000000000000        2.5000000000000001E-002
#  source-end coordinates
#    1.4999999999999999E-004   0.0000000000000000        2.5000000000000001E-002
#  source moment               1.0000000000000000
# Segmented line source
# Number of source edges:
#            1
# Source edges and nodes:
#       297162
#          162         161
# *************************************
# Detecting surface edges
# Check if PEC present
# Check if PML present
# Detecting PML elements
# Number of PML elements:
#        24411
# Number of non-PML elements:
#       387591
# To Check, number of non-PML elements:
#       387591
# *************************************
# Checking elements for all receivers
# Receiver number and its Earth element:
#            1      183986
# Receiver number and its Earth element:
#            2      338837
# Receiver number and its Earth element:
#            3      164772
# Receiver number and its Earth element:
#            4      163305
# Receiver number and its Earth element:
#            5      248743
# Receiver number and its Earth element:
#            6      188808
# Receiver number and its Earth element:
#            7      188730
# Receiver number and its Earth element:
#            8      155978
# Receiver number and its Earth element:
#            9      182644
# Receiver number and its Earth element:
#           10      222672
# Receiver number and its Earth element:
#           11      169907
# Receiver number and its Earth element:
#           12      180015
# Receiver number and its Earth element:
#           13       21065
# Receiver number and its Earth element:
#           14      127036
# Receiver number and its Earth element:
#           15      129945
# Receiver number and its Earth element:
#           16      221581
# Receiver number and its Earth element:
#           17      244923
# Receiver number and its Earth element:
#           18      174633
# Receiver number and its Earth element:
#           19      160858
# Receiver number and its Earth element:
#           20      127985
# Receiver number and its Earth element:
#           21      265608
# Receiver number and its Earth element:
#           22      139376
# Receiver number and its Earth element:
#           23      236387
# Receiver number and its Earth element:
#           24      135935
# Receiver number and its Earth element:
#           25      130712
# Receiver number and its Earth element:
#           26       59038
# Receiver number and its Earth element:
#           27      147540
# Receiver number and its Earth element:
#           28      234293
# Receiver number and its Earth element:
#           29      239167
# Receiver number and its Earth element:
#           30      205972
# Receiver number and its Earth element:
#           31      189297
# Receiver number and its Earth element:
#           32      129706
# Receiver number and its Earth element:
#           33      136807
# Receiver number and its Earth element:
#           34      121950
# Receiver number and its Earth element:
#           35      123814
# Receiver number and its Earth element:
#           36      278059
# Receiver number and its Earth element:
#           37       78820
# Receiver number and its Earth element:
#           38      257054
# Receiver number and its Earth element:
#           39      205157
# Receiver number and its Earth element:
#           40      184074
# Receiver number and its Earth element:
#           41      103832
# Receiver number and its Earth element:
#           42      211932
# Receiver number and its Earth element:
#           43       98174
# Receiver number and its Earth element:
#           44      218276
# Receiver number and its Earth element:
#           45      118460
# Receiver number and its Earth element:
#           46      176495
# Receiver number and its Earth element:
#           47      164448
# Receiver number and its Earth element:
#           48      193895
# **********************************
#  Loop for frequency   100000000.00000000      [Hz]
# **********************************
# Evaluating PML complex stretching factors
#  Simple Reciprocal PML decay type
# Setting up system matrix
# Calculating global source vector
# Source length:
#    2.9999999999999997E-004
# Calculating RHS of dual problem
# Applying Dirichlet boundary condition
# Number of non-zero elements in Agcoo after applying BC:
#     14318991
# **********************************
# Solving primal and dual problems with MUMPS
#  OMP num threads          20
#
# Entering ZMUMPS 5.7.3 with JOB, N, NNZ =   6      488108        4045619
#       executing #MPI =      1 and #OMP =     20
#
#  =================================================
#  MUMPS compiled with option -Dmetis
#  MUMPS compiled with option -Dpord
#  MUMPS compiled with option -Dscotch
#  =================================================
# L D L^T Solver for general symmetric matrices
# Type of parallelism: Working host
#
#  ****** ANALYSIS STEP ********
#
#  Processing a graph of size:    488108
#  Average density of rows/columns =   15
#  Ordering based on SCOTCH
#  ELAPSED TIME SPENT IN SCOTCH reordering =      9.8058
#
# Leaving analysis phase with  ...
#  INFOG(1)                                       =               0
#  INFOG(2)                                       =               0
#  -- (20) Number of entries in factors (estim.)  =       150009410
#  --  (3) Real space for factors    (estimated)  =       157692905
#  --  (4) Integer space for factors (estimated)  =         5179872
#  --  (5) Maximum frontal size      (estimated)  =            3509
#  --  (6) Number of nodes in the tree            =           37437
#  -- (32) Type of analysis effectively used      =               1
#  --  (7) Ordering option effectively used       =               3
#  ICNTL (6) Maximum transversal option           =               0
#  ICNTL (7) Pivot order option                   =               3
#  ICNTL(12) Ordering symmetric indef. matrices   =               1
#  ICNTL(13) Parallelism/splitting of root node   =               0
#  ICNTL(14) Percentage of memory relaxation      =              20
#  ICNTL(15) Analysis by block effectively used   =               0
#  ICNTL(18) Distributed input matrix (on if >0)  =               0
#  ICNTL(32) Forward elimination during facto.    =               0
#  ICNTL(35) BLR activation                       =               0
#  ICNTL(48) Tree based multithreading (effective)=               1
#  ICNTL(58) Symbolic factorization option        =               2
#  Number of level 2 nodes                        =               0
#  Number of split nodes                          =               0
#  RINFOG(1) Operations during elimination (estim)= 1.549D+11
#
#  MEMORY ESTIMATIONS ...
#  Estimations with standard Full-Rank (FR) factorization:
#     Total space in MBytes, IC factorization      (INFOG(17)):            3357
#     Total space in MBytes,  OOC factorization    (INFOG(27)):            1409
#
#  Elapsed time in analysis driver=      10.0409
#
#
# ****** FACTORIZATION STEP ********
#
#  GLOBAL STATISTICS PRIOR NUMERICAL FACTORIZATION ...
#  Number of working processes                =               1
#  ICNTL(22) Out-of-core option               =               0
#  ICNTL(35) BLR activation (eff. choice)     =               0
#  ICNTL(37) BLR CB compression (eff. choice) =               0
#  ICNTL(49) Compact workarray S (end facto.) =               0
#  ICNTL(14) Memory relaxation                =              20
#  INFOG(3) Real space for factors (estimated)=       157692905
#  INFOG(4) Integer space for factors (estim.)=         5179872
#  Maximum frontal size (estimated)           =            3509
#  Number of nodes in the tree                =           37437
#  ICNTL(23) Memory allowed (value on host)   =               0
#            Sum over all procs               =               0
#  Memory provided by user, sum of LWK_USER   =               0
#  Effective threshold for pivoting, CNTL(1)  =      0.1000D-01
#
#  Statistics on the scaling phase
#  Elapsed time for scaling                   =      0.1706
#  Max difference from 1 after scaling the entries for ONE-NORM (option 7/8)   = 0.28D+00
#
#  Effective size of S     (based on INFO(39))=             62262743
#  Elapsed time to reformat/distribute matrix =      0.0972
#
#
#  Allocated buffers
#  ------------------
#  Size of reception buffer in bytes ...... =       140000
#  Size of async. emission buffer (bytes).. =       157988
#  Small emission buffer (bytes) .......... =           20
#
#  ** Memory allocated, total in Mbytes           (INFOG(19)):        3356
#  ** Memory effectively used, total in Mbytes    (INFOG(22)):        3190
#
#  Flops under L0 layer                       =   6.310D+10
#  Elapsed time under L0                      =     44.5363
#
#  Elapsed time for factorization                     =    159.6972
#
# Leaving factorization with ...
#  RINFOG (2) Operations in node assembly             = 2.232D+08
#  ------ (3) Operations in node elimination          = 1.549D+11
#  ICNTL  (8) Scaling effectively used                =               7
#  INFOG  (9) Real space for factors                  =       157692905
#  INFOG (10) Integer space for factors               =         5179872
#  INFOG (11) Maximum front size                      =            3509
#  INFOG (29) Number of entries in factors            =       150009410
#  INFOG (13) Number of delayed pivots                =               0
#  Number of 2x2 pivots in type 1 nodes               =               1
#  Number of 2x2 pivots in type 2 nodes               =               0
#  RINFOG(19) Smallest pivot WITH perturbed pivots    = 5.651D-08
#  RINFOG(20) Smallest pivot WITHOUT perturbed pivots = 5.651D-08
#  RINFOG(21) Largest pivot in absolute value         = 3.996D+00
#  INFOG (24) Effective value of ICNTL(12)            =               1
#  INFOG (14) Number of memory compress               =               0
#
#  Elapsed time in factorization driver               =    159.9825
#
#
#  ****** SOLVE & CHECK STEP ********
#
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           2
#   --- (20)                                     =           0
#   --- (21)                                     =           0
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           1
#
#  ERROR ANALYSIS
#
#  RESIDUAL IS ............ (INF-NORM)        = 5.36D-07
#                        .. (2-NORM)          = 1.88D-06
#  RINFOG(4):NORM OF input  Matrix  (INF-NORM)= 6.40D+01
#  RINFOG(5):NORM OF Computed SOLUT (INF-NORM)= 1.30D+12
#  RINFOG(6):SCALED RESIDUAL ...... (INF-NORM)= 6.44D-21
#  RINFOG(7):COMPONENTWISE SCALED RESIDUAL(W1)= 1.08D-15
#  ------(8):---------------------------- (W2)= 4.77D-23
#  ** Space in MBYTES used for solve                        :      2906
#
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.096440
#  Time in solution step (fwd/bwd)  =       5.575058
#   .. Time in forward (fwd) step   =          3.445683
#   .. Time in backward (bwd) step  =          2.129370
#  Time to gather solution(cent.sol)=       0.082427
#  Time for distributed solution    =       0.000000
#
#  Elapsed time in solve driver=       5.9898
#
# Entering ZMUMPS 5.7.3 with JOB =  -2
#       executing #MPI =      1 and #OMP =     20
# **********************************
# No error estimation!
# ***********************************************************
# Writing Volumetric Field Distribution in Entire Domain Now
#  Domain fields are written into in/GPR_model_tl_pml_15.1.vtk
# Allocated variables were deallocated
# *************************************
# *************************************
# Modelling with elfe3D completed
# Output files are located in: /out
# *************************************
# *************************************
# CPU time to run elfe3D = 3865.219 seconds.
# Real time to run elfe3D =   261.524 seconds.
#
# ✓  done in 261.7s
#
# >>> tl_pml_17p5
# [0.0, -1.0]
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\GPR_model_tl_pml_17p5.poly
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\elfe3D_input.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\source.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\regionparameters.txt
# Input generation complete.
# ── TetGen ────────────────────────────────────────────
#    cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/io/inputs/in && /usr/bin/tetgen -pq1.2kAaen GPR_model_tl_pml_17p5.poly
#
# Opening GPR_model_tl_pml_17p5.poly.
# Delaunizing vertices...
# Delaunay seconds:  0.004726
# Creating surface mesh ...
# Surface mesh seconds:  0.001555
# Constrained Delaunay...
# Constrained Delaunay seconds:  0.001978
# Removing exterior tetrahedra ...
# Spreading region attributes.
# Exterior tets removal seconds:  0.000179
# Refining mesh...
# Refinement seconds:  1.34521
# Optimizing mesh...
# Optimization seconds:  0.062236
#
# Writing GPR_model_tl_pml_17p5.1.node.
# Writing GPR_model_tl_pml_17p5.1.ele.
# Writing GPR_model_tl_pml_17p5.1.face.
# Writing GPR_model_tl_pml_17p5.1.edge.
# Writing GPR_model_tl_pml_17p5.1.vtk.
# Writing GPR_model_tl_pml_17p5.1.neigh.
#
# Output seconds:  1.33874
# Total running seconds:  2.75473
#
# Statistics:
#
#   Input points: 242
#   Input facets: 127
#   Input segments: 369
#   Input holes: 0
#   Input regions: 45
#
#   Mesh points: 68811
#   Mesh tetrahedra: 410613
#   Mesh faces: 827655
#   Mesh edges: 485852
#   Mesh faces on facets: 52315
#   Mesh edges on segments: 2476
#   Steiner points inside domain: 43942
#   Steiner points on facets:  22520
#   Steiner points on segments:  2107
#
#
# ✓  done in 8.0s
# ── elfe3d_gpr ────────────────────────────────────────
#    wsl bash -c cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/io/inputs && /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/elfe3D_GPR/elfe3d_gpr
#
# ***************************************
# GPR forward modelling with elfe3D_GPR
# ***************************************
# Your forward problem is solved with
#  MUMPS
# *************************************
# Reading refinement information
# Your mesh will be refined
#  for             0 refinement steps
#  or until     5000000 unknowns
#  with error estim. method           3
#  with refinement strategy           1
# Your output files will be generated in: /out
# Field components in the domain will be in *.vtk file in: /in
# *************************************
# Reading model definitions
# Your input meshfile is called
#  in/GPR_model_tl_pml_17p5.
# Your mesh has
#        68811 Nodes
#       410613 Elements
#       485852 Edges (dof)
# *************************************
# Assembling connectivity arrays
# Calculating interpolation coefficients
# Obtaining model properties
# *************************************
# Source parameters:
#  CSTYPE           6
#  source-start coordinates:
#   -1.4999999999999999E-004   0.0000000000000000        2.5000000000000001E-002
#  source-end coordinates
#    1.4999999999999999E-004   0.0000000000000000        2.5000000000000001E-002
#  source moment               1.0000000000000000
# Segmented line source
# Number of source edges:
#            1
# Source edges and nodes:
#        92513
#          161         162
# *************************************
# Detecting surface edges
# Check if PEC present
# ...
#  Time to gather solution(cent.sol)=       0.072199
#  Time for distributed solution    =       0.000000
#
#  Elapsed time in solve driver=       6.4489
#
# Entering ZMUMPS 5.7.3 with JOB =  -2
#       executing #MPI =      1 and #OMP =     20
# **********************************
# No error estimation!
# ***********************************************************
# Writing Volumetric Field Distribution in Entire Domain Now
#  Domain fields are written into in/GPR_model_tl_pml_22p5.1.vtk
# Allocated variables were deallocated
# *************************************
# *************************************
# Modelling with elfe3D completed
# Output files are located in: /out
# *************************************
# *************************************
# CPU time to run elfe3D = 4165.248 seconds.
# Real time to run elfe3D =   288.322 seconds.
#
# ✓  done in 288.6s
#
# >>> tl_pml_25
# [0.0, -1.0]
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\GPR_model_tl_pml_25.poly
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\elfe3D_input.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\source.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\io\inputs\in\regionparameters.txt
# Input generation complete.
# ── TetGen ────────────────────────────────────────────
#    cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/io/inputs/in && /usr/bin/tetgen -pq1.2kAaen GPR_model_tl_pml_25.poly
#
# Opening GPR_model_tl_pml_25.poly.
# Delaunizing vertices...
# Delaunay seconds:  0.00384
# Creating surface mesh ...
# Surface mesh seconds:  0.001242
# Constrained Delaunay...
# Constrained Delaunay seconds:  0.001773
# Removing exterior tetrahedra ...
# Spreading region attributes.
# Exterior tets removal seconds:  0.000218
# Refining mesh...
# Refinement seconds:  1.48461
# Optimizing mesh...
# Optimization seconds:  0.067816
#
# Writing GPR_model_tl_pml_25.1.node.
# Writing GPR_model_tl_pml_25.1.ele.
# Writing GPR_model_tl_pml_25.1.face.
# Writing GPR_model_tl_pml_25.1.edge.
# Writing GPR_model_tl_pml_25.1.vtk.
# Writing GPR_model_tl_pml_25.1.neigh.
#
# Output seconds:  1.41385
# Total running seconds:  2.97353
#
# Statistics:
#
#   Input points: 242
#   Input facets: 127
#   Input segments: 369
#   Input holes: 0
#   Input regions: 45
#
#   Mesh points: 66615
#   Mesh tetrahedra: 397508
#   Mesh faces: 801427
#   Mesh edges: 470533
#   Mesh faces on facets: 51078
#   Mesh edges on segments: 2447
#   Steiner points inside domain: 42375
#   Steiner points on facets:  21920
#   Steiner points on segments:  2078
#
#
# ✓  done in 8.5s
# ── elfe3d_gpr ────────────────────────────────────────
#    wsl bash -c cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/io/inputs && /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/elfe3D_GPR/elfe3d_gpr
#
# ***************************************
# GPR forward modelling with elfe3D_GPR
# ***************************************
# Your forward problem is solved with
#  MUMPS
# *************************************
# Reading refinement information
# Your mesh will be refined
#  for             0 refinement steps
#  or until     5000000 unknowns
#  with error estim. method           3
#  with refinement strategy           1
# Your output files will be generated in: /out
# Field components in the domain will be in *.vtk file in: /in
# *************************************
# Reading model definitions
# Your input meshfile is called
#  in/GPR_model_tl_pml_25.
# Your mesh has
#        66615 Nodes
#       397508 Elements
#       470533 Edges (dof)
# *************************************
# Assembling connectivity arrays
# Calculating interpolation coefficients
# Obtaining model properties
# *************************************
# Source parameters:
#  CSTYPE           6
#  source-start coordinates:
#   -1.4999999999999999E-004   0.0000000000000000        2.5000000000000001E-002
#  source-end coordinates
#    1.4999999999999999E-004   0.0000000000000000        2.5000000000000001E-002
#  source moment               1.0000000000000000
# Segmented line source
# Number of source edges:
#            1
# Source edges and nodes:
#       361623
#          161         162
# *************************************
# Detecting surface edges
# Check if PEC present
# Check if PML present
# Detecting PML elements
# Number of PML elements:
#        15730
# Number of non-PML elements:
#       381778
# To Check, number of non-PML elements:
#       381778
# *************************************
# Checking elements for all receivers
# Receiver number and its Earth element:
#            1      117808
# Receiver number and its Earth element:
#            2       82458
# Receiver number and its Earth element:
#            3      193555
# Receiver number and its Earth element:
#            4      141069
# Receiver number and its Earth element:
#            5      138087
# Receiver number and its Earth element:
#            6      148260
# Receiver number and its Earth element:
#            7      247315
# Receiver number and its Earth element:
#            8      147549
# Receiver number and its Earth element:
#            9      135703
# Receiver number and its Earth element:
#           10       82648
# Receiver number and its Earth element:
#           11      186754
# Receiver number and its Earth element:
#           12       35159
# Receiver number and its Earth element:
#           13      143843
# Receiver number and its Earth element:
#           14      216932
# Receiver number and its Earth element:
#           15      186485
# Receiver number and its Earth element:
#           16      236383
# Receiver number and its Earth element:
#           17      135868
# Receiver number and its Earth element:
#           18      179735
# Receiver number and its Earth element:
#           19        1458
# Receiver number and its Earth element:
#           20      147014
# Receiver number and its Earth element:
#           21      183846
# Receiver number and its Earth element:
#           22      215800
# Receiver number and its Earth element:
#           23      183221
# Receiver number and its Earth element:
#           24      138782
# Receiver number and its Earth element:
#           25      122255
# Receiver number and its Earth element:
#           26      133624
# Receiver number and its Earth element:
#           27      202048
# Receiver number and its Earth element:
#           28      150353
# Receiver number and its Earth element:
#           29      194822
# Receiver number and its Earth element:
#           30      135543
# Receiver number and its Earth element:
#           31      148536
# Receiver number and its Earth element:
#           32      176608
# Receiver number and its Earth element:
#           33      126815
# Receiver number and its Earth element:
#           34      135074
# Receiver number and its Earth element:
#           35      276409
# Receiver number and its Earth element:
#           36      191570
# Receiver number and its Earth element:
#           37      177505
# Receiver number and its Earth element:
#           38      269473
# Receiver number and its Earth element:
#           39      212058
# Receiver number and its Earth element:
#           40      147383
# Receiver number and its Earth element:
#           41      254431
# Receiver number and its Earth element:
#           42       78126
# Receiver number and its Earth element:
#           43       37551
# Receiver number and its Earth element:
#           44      160737
# Receiver number and its Earth element:
#           45      190093
# Receiver number and its Earth element:
#           46      172884
# Receiver number and its Earth element:
#           47      135689
# Receiver number and its Earth element:
#           48      239879
# **********************************
#  Loop for frequency   100000000.00000000      [Hz]
# **********************************
# Evaluating PML complex stretching factors
#  Simple Reciprocal PML decay type
# Setting up system matrix
# Calculating global source vector
# Source length:
#    2.9999999999999997E-004
# Calculating RHS of dual problem
# Applying Dirichlet boundary condition
# Number of non-zero elements in Agcoo after applying BC:
#     13813913
# **********************************
# Solving primal and dual problems with MUMPS
#  OMP num threads          20
#
# Entering ZMUMPS 5.7.3 with JOB, N, NNZ =   6      470533        3902519
#       executing #MPI =      1 and #OMP =     20
#
#  =================================================
#  MUMPS compiled with option -Dmetis
#  MUMPS compiled with option -Dpord
#  MUMPS compiled with option -Dscotch
#  =================================================
# L D L^T Solver for general symmetric matrices
# Type of parallelism: Working host
#
#  ****** ANALYSIS STEP ********
#
#  Processing a graph of size:    470533
#  Average density of rows/columns =   15
#  Ordering based on SCOTCH
#  ELAPSED TIME SPENT IN SCOTCH reordering =      9.4989
#
# Leaving analysis phase with  ...
#  INFOG(1)                                       =               0
#  INFOG(2)                                       =               0
#  -- (20) Number of entries in factors (estim.)  =       140645421
#  --  (3) Real space for factors    (estimated)  =       147952091
#  --  (4) Integer space for factors (estimated)  =         4969014
#  --  (5) Maximum frontal size      (estimated)  =            3333
#  --  (6) Number of nodes in the tree            =           35357
#  -- (32) Type of analysis effectively used      =               1
#  --  (7) Ordering option effectively used       =               3
#  ICNTL (6) Maximum transversal option           =               0
#  ICNTL (7) Pivot order option                   =               3
#  ICNTL(12) Ordering symmetric indef. matrices   =               1
#  ICNTL(13) Parallelism/splitting of root node   =               0
#  ICNTL(14) Percentage of memory relaxation      =              20
#  ICNTL(15) Analysis by block effectively used   =               0
#  ICNTL(18) Distributed input matrix (on if >0)  =               0
#  ICNTL(32) Forward elimination during facto.    =               0
#  ICNTL(35) BLR activation                       =               0
#  ICNTL(48) Tree based multithreading (effective)=               1
#  ICNTL(58) Symbolic factorization option        =               2
#  Number of level 2 nodes                        =               0
#  Number of split nodes                          =               0
#  RINFOG(1) Operations during elimination (estim)= 1.365D+11
#
#  MEMORY ESTIMATIONS ...
#  Estimations with standard Full-Rank (FR) factorization:
#     Total space in MBytes, IC factorization      (INFOG(17)):            3159
#     Total space in MBytes,  OOC factorization    (INFOG(27)):            1270
#
#  Elapsed time in analysis driver=       9.7508
#
#
# ****** FACTORIZATION STEP ********
#
#  GLOBAL STATISTICS PRIOR NUMERICAL FACTORIZATION ...
#  Number of working processes                =               1
#  ICNTL(22) Out-of-core option               =               0
#  ICNTL(35) BLR activation (eff. choice)     =               0
#  ICNTL(37) BLR CB compression (eff. choice) =               0
#  ICNTL(49) Compact workarray S (end facto.) =               0
#  ICNTL(14) Memory relaxation                =              20
#  INFOG(3) Real space for factors (estimated)=       147952091
#  INFOG(4) Integer space for factors (estim.)=         4969014
#  Maximum frontal size (estimated)           =            3333
#  Number of nodes in the tree                =           35357
#  ICNTL(23) Memory allowed (value on host)   =               0
#            Sum over all procs               =               0
#  Memory provided by user, sum of LWK_USER   =               0
#  Effective threshold for pivoting, CNTL(1)  =      0.1000D-01
#
#  Statistics on the scaling phase
#  Elapsed time for scaling                   =      0.1621
#  Max difference from 1 after scaling the entries for ONE-NORM (option 7/8)   = 0.17D+00
#
#  Effective size of S     (based on INFO(39))=             56297784
#  Elapsed time to reformat/distribute matrix =      0.0892
#
#
#  Allocated buffers
#  ------------------
#  Size of reception buffer in bytes ...... =       140000
#  Size of async. emission buffer (bytes).. =       150064
#  Small emission buffer (bytes) .......... =           20
#
#  ** Memory allocated, total in Mbytes           (INFOG(19)):        3142
#  ** Memory effectively used, total in Mbytes    (INFOG(22)):        2992
#
#  Flops under L0 layer                       =   5.726D+10
#  Elapsed time under L0                      =     55.7779
#
#  Elapsed time for factorization                     =    161.7723
#
# Leaving factorization with ...
#  RINFOG (2) Operations in node assembly             = 2.147D+08
#  ------ (3) Operations in node elimination          = 1.365D+11
#  ICNTL  (8) Scaling effectively used                =               7
#  INFOG  (9) Real space for factors                  =       147952091
#  INFOG (10) Integer space for factors               =         4969014
#  INFOG (11) Maximum front size                      =            3333
#  INFOG (29) Number of entries in factors            =       140645421
#  INFOG (13) Number of delayed pivots                =               0
#  Number of 2x2 pivots in type 1 nodes               =               0
#  Number of 2x2 pivots in type 2 nodes               =               0
#  RINFOG(19) Smallest pivot WITH perturbed pivots    = 5.785D-08
#  RINFOG(20) Smallest pivot WITHOUT perturbed pivots = 5.785D-08
#  RINFOG(21) Largest pivot in absolute value         = 5.485D+00
#  INFOG (24) Effective value of ICNTL(12)            =               1
#  INFOG (14) Number of memory compress               =               0
#
#  Elapsed time in factorization driver               =    162.0403
#
#
#  ****** SOLVE & CHECK STEP ********
#
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           2
#   --- (20)                                     =           0
#   --- (21)                                     =           0
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           1
#
#  ERROR ANALYSIS
#
#  RESIDUAL IS ............ (INF-NORM)        = 5.07D-07
#                        .. (2-NORM)          = 1.50D-06
#  RINFOG(4):NORM OF input  Matrix  (INF-NORM)= 1.09D+02
#  RINFOG(5):NORM OF Computed SOLUT (INF-NORM)= 1.10D+12
#  RINFOG(6):SCALED RESIDUAL ...... (INF-NORM)= 4.24D-21
#  RINFOG(7):COMPONENTWISE SCALED RESIDUAL(W1)= 8.25D-16
#  ------(8):---------------------------- (W2)= 3.51D-23
#  ** Space in MBYTES used for solve                        :      2720
#
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.155015
#  Time in solution step (fwd/bwd)  =       5.498847
#   .. Time in forward (fwd) step   =          3.561436
#   .. Time in backward (bwd) step  =          1.937402
#  Time to gather solution(cent.sol)=       0.042085
#  Time for distributed solution    =       0.000000
#
#  Elapsed time in solve driver=       5.8981
#
# Entering ZMUMPS 5.7.3 with JOB =  -2
#       executing #MPI =      1 and #OMP =     20
# **********************************
# No error estimation!
# ***********************************************************
# Writing Volumetric Field Distribution in Entire Domain Now
#  Domain fields are written into in/GPR_model_tl_pml_25.1.vtk
# Allocated variables were deallocated
# *************************************
# *************************************
# Modelling with elfe3D completed
# Output files are located in: /out
# *************************************
# *************************************
# CPU time to run elfe3D = 3898.964 seconds.
# Real time to run elfe3D =   270.026 seconds.
#
# ✓  done in 270.2s

# %% [markdown]
# ### 7c — Load results and plot

# %%
sweep_datasets = []
for s, d in zip(sweep_surveys, denoms):
    result_txt = s.io.output_dir / 'electric_fields_receiver_line.txt'
    ds = ElfeLoader(
        filepath    = str(result_txt),
        label       = rf'$\lambda_2/{d}$',
        num_endfire = 48,
    ).endfire()
    sweep_datasets.append(ds)

print(f'Loaded {len(sweep_datasets)} sweep datasets')
# Out:
# Loaded 7 sweep datasets

# %%
xtick_labels = [rf'$\dfrac{{\lambda_2}}{{{d}}}$' for d in denoms]

ErrorStatPlot(
    sweep_datasets,
    reference    = semi_analytical,
    param_values = [wave2 / d for d in denoms],
    xtick_labels = xtick_labels,
).plot()

# %%
# All sweep runs on one comparison and one error plot
ReceiverLinePlot([semi_analytical] + sweep_datasets).plot(suptitle='Endfire - PML thickness sweep')
ReceiverLineErrorPlot(sweep_datasets, reference=semi_analytical).plot(suptitle='Errors vs semi_analytical - PML thickness sweep')
