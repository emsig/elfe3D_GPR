# %% [markdown]
# # Anomaly model
#
# Forward model with an embedded rectangular anomaly (eps_r = 20) in a two-layer background.
#
# The background reference is the Evert two-layer solution (no anomaly). The difference between the anomaly and background responses is the target signature.

# %% [markdown]
# # Add multi-anomaly capability

# %%
import sys, os, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# ── locate master\ from examples\<name>\ (two levels up) ─────────────────
MASTER = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..', '..'))

sys.path.insert(0, os.path.join(MASTER, 'io'))
sys.path.insert(0, os.path.join(MASTER, 'io', 'inputs'))
sys.path.insert(0, os.path.join(MASTER, 'io', 'outputs'))

# inputs
from survey import GPRSurvey
from anomalies import SphereAnomaly

# runner
from runner import ProjectPaths, run_tetgen, run_solver

# outputs
from fieldreader import AnalyticalLoader, ElfeLoader, load_elfe_batch
from postprocess import field_error, all_errors, error_stats
from visualize   import (ReceiverLinePlot, ReceiverLineErrorPlot,
                          ReceiverLineCombined, ErrorHistogramPlot)

# %% [markdown]
# ---
# ## Paths

# %%
# ── set once per machine ───────────────────────────────────────────────────
paths = ProjectPaths(
    master_dir = MASTER,
    exec_rel   = r'elfe3D_GPR\elfe3d_gpr',
    use_wsl    = True,   # False if running from inside WSL
)

print('master   :', MASTER)
print('exec     :', paths.exec_path())
# Out:
# master   : f:\Projects\EMGeoInversion\elfe3D_GPR
# exec     : f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\elfe3d_gpr

# %% [markdown]
# ---
# ## 1 — Build and write inputs
#
# Same background as the two-layered example, plus a `SphereAnomaly`

# %%
f    = 100e6
wave = 3e8 / f

BASE_DIR = os.path.join(MASTER, 'elfe3D_GPR')

survey = GPRSurvey.build(
    experiment_name="anomaly_sphere",
    base_dir=BASE_DIR,

    # Domain
    x_e=[-wave/10, 1 + wave/10],
    y_e=[-wave/10, wave/10],
    z_e=[-1.0 - wave/10/3, wave/10],

    # Materials — air + 2 earth layers
    air_eps_r=1.0,
    air_sigma=1e-16,
    layer_thicknesses=[1.0, wave/10/3],
    layer_eps_r=[4.0, 9.0],
    layer_sigma=[1e-4, 1e-3],
    layer_mu_r=[1.0, 1.0],
    layer_sigma_m=[0.0, 0.0],

    anomalies=[
        SphereAnomaly(
            center=(0.0, 0.0, -0.7),
            radius=wave/16,
            properties=(20, 1e-4, 1.0, 0.0),   # (eps_r, sigma, mu_r, sigma_m)
        )
    ],

    # Source
    ricker_central_f=f,
    num_points_per_range=1,
    antenna_position=[0.0, 0.0, 0.025],
    source_type=6,
    current_direction=1,
    num_segments=1,
    s_f=250,
    bh_f=1.0,
    box_present=False,
    box_x=[-1 + 0.75, 1 + 0.375],
    m=5,

    # Receivers
    num_receivers_inline=48,
    num_receivers_endfire=0,
    num_receivers_oblique=0,

    # Solver
    solver_type=2,
    max_ref_steps=0,
    max_unknowns=5_000_000,
    accuracy_tol=3e-5,
    output_fields_vtk=1,

    # PML
    num_pml_layers=1,
    pml_layer_thickness=wave/10,
    pml_type="lin",
    pml_decay_type=1,

    least_samples_per_wavelength=10,
)

survey.generate()

print('poly :', survey.io.poly_file)
# Out:
# odepths: [0.075, 0.0375, 0.025]
# Source antenna length: 0.0006 m
# Receiver antenna depth: -0.00015 m
# [0.0, -1.0]
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\in\GPR_model_anomaly_sphere.poly
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\in\elfe3D_input.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\in\source.txt
# Written: f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\in\regionparameters.txt
# Input generation complete.
# poly : f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\in\GPR_model_anomaly_sphere.poly

# %% [markdown]
# ---
# ## 2 — Mesh with TetGen

# %%
run_tetgen(paths, survey.io.poly_file)
# Out:
# ── TetGen ────────────────────────────────────────────
#    cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/elfe3D_GPR/in && /usr/bin/tetgen -pq1.2kAaen GPR_model_anomaly_sphere.poly
#
# Opening GPR_model_anomaly_sphere.poly.
# Delaunizing vertices...
# Delaunay seconds:  0.01739
# Creating surface mesh ...
# Surface mesh seconds:  0.003394
# Constrained Delaunay...
# Constrained Delaunay seconds:  0.01356
# Removing exterior tetrahedra ...
# Spreading region attributes.
# Exterior tets removal seconds:  0.000902
# Refining mesh...
# Refinement seconds:  1.07411
# Optimizing mesh...
# Optimization seconds:  0.05804
#
# Writing GPR_model_anomaly_sphere.1.node.
# Writing GPR_model_anomaly_sphere.1.ele.
# Writing GPR_model_anomaly_sphere.1.face.
# Writing GPR_model_anomaly_sphere.1.edge.
# Writing GPR_model_anomaly_sphere.1.vtk.
# Writing GPR_model_anomaly_sphere.1.neigh.
#
# Output seconds:  0.840175
# Total running seconds:  2.00773
#
# Statistics:
#
#   Input points: 2804
#   Input facets: 5247
#   Input segments: 8049
#   Input holes: 0
#   Input regions: 46
#
#   Mesh points: 52265
#   Mesh tetrahedra: 315786
#   Mesh faces: 635110
#   Mesh edges: 371588
#   Mesh faces on facets: 38220
#   Mesh edges on segments: 9517
#   Steiner points inside domain: 34097
#   Steiner points on facets:  13896
#   Steiner points on segments:  1468
#
#
# ✓  done in 6.1s

# %% [markdown]
# ---
# ## 3 — Run solver

# %%
run_solver(paths,survey)
# Out:
# ── elfe3d_gpr ────────────────────────────────────────
#    wsl bash -c cd /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/elfe3D_GPR && /mnt/f/Projects/EMGeoInversion/elfe3D_GPR/elfe3D_GPR/elfe3d_gpr
#
# ***************************************
# GPR forward modelling with elfe3D_GPR
# ***************************************
# Your forward problem is solved with
#  MUMPS
# *************************************
# Reading refinement information
# Your mesh will be refined
#  for             0 refinement steps
#  or until     5000000 unknowns
#  with error estim. method           3
#  with refinement strategy           1
# Your output files will be generated in: /out
# Field components in the domain will be in *.vtk file in: /in
# *************************************
# Reading model definitions
# Your input meshfile is called
#  in/GPR_model_anomaly_sphere.
# Your mesh has
#        52265 Nodes
#       315786 Elements
#       371588 Edges (dof)
# *************************************
# Assembling connectivity arrays
# Calculating interpolation coefficients
# Obtaining model properties
# *************************************
# Source parameters:
#  CSTYPE           6
#  source-start coordinates:
#   -2.9999999999999997E-004   0.0000000000000000        2.5000000000000001E-002
#  source-end coordinates
#    2.9999999999999997E-004   0.0000000000000000        2.5000000000000001E-002
#  source moment               1.0000000000000000
# Segmented line source
# Number of source edges:
#            1
# Source edges and nodes:
#       316089
#          161         162
# *************************************
# Detecting surface edges
# Check if PEC present
# Check if PML present
# Detecting PML elements
# Number of PML elements:
#        52175
# Number of non-PML elements:
#       263611
# To Check, number of non-PML elements:
#       263611
# *************************************
# Checking elements for all receivers
# Receiver number and its Earth element:
#            1      174326
# Receiver number and its Earth element:
#            2      216323
# Receiver number and its Earth element:
#            3      204629
# Receiver number and its Earth element:
#            4      131447
# Receiver number and its Earth element:
#            5      161663
# Receiver number and its Earth element:
#            6       44232
# Receiver number and its Earth element:
#            7      135339
# Receiver number and its Earth element:
#            8      159608
# Receiver number and its Earth element:
#            9      174537
# Receiver number and its Earth element:
#           10      155749
# Receiver number and its Earth element:
#           11       37911
# Receiver number and its Earth element:
#           12       73879
# Receiver number and its Earth element:
#           13      225671
# Receiver number and its Earth element:
#           14      113548
# Receiver number and its Earth element:
#           15       79520
# Receiver number and its Earth element:
#           16      180513
# Receiver number and its Earth element:
#           17       76754
# Receiver number and its Earth element:
#           18      177980
# Receiver number and its Earth element:
#           19      162393
# Receiver number and its Earth element:
#           20      165924
# Receiver number and its Earth element:
#           21      210411
# Receiver number and its Earth element:
#           22      223599
# Receiver number and its Earth element:
#           23      253969
# Receiver number and its Earth element:
#           24      213467
# Receiver number and its Earth element:
#           25      185366
# Receiver number and its Earth element:
#           26      215819
# Receiver number and its Earth element:
#           27       41604
# Receiver number and its Earth element:
#           28      205183
# Receiver number and its Earth element:
#           29       60195
# Receiver number and its Earth element:
#           30      113750
# Receiver number and its Earth element:
#           31      234936
# Receiver number and its Earth element:
#           32      159579
# Receiver number and its Earth element:
#           33      123412
# Receiver number and its Earth element:
#           34      167432
# Receiver number and its Earth element:
#           35      179978
# Receiver number and its Earth element:
#           36      133512
# Receiver number and its Earth element:
#           37      114188
# Receiver number and its Earth element:
#           38      158261
# Receiver number and its Earth element:
#           39      218800
# Receiver number and its Earth element:
#           40      141388
# Receiver number and its Earth element:
#           41       65116
# Receiver number and its Earth element:
#           42      133549
# Receiver number and its Earth element:
#           43      122423
# Receiver number and its Earth element:
#           44      194195
# Receiver number and its Earth element:
#           45       30243
# Receiver number and its Earth element:
#           46      106214
# Receiver number and its Earth element:
#           47      173127
# Receiver number and its Earth element:
#           48       77913
# **********************************
#  Loop for frequency   100000000.00000000      [Hz]
# **********************************
# Evaluating PML complex stretching factors
#  Simple Reciprocal PML decay type
# Setting up system matrix
# Calculating global source vector
# Source length:
#    5.9999999999999995E-004
# Calculating RHS of dual problem
# Applying Dirichlet boundary condition
# Number of non-zero elements in Agcoo after applying BC:
#     11109434
# **********************************
# Solving primal and dual problems with MUMPS
#  OMP num threads          20
#
# Entering ZMUMPS 5.7.3 with JOB, N, NNZ =   6      371588        3136939
#       executing #MPI =      1 and #OMP =     20
#
#  =================================================
#  MUMPS compiled with option -Dmetis
#  MUMPS compiled with option -Dpord
#  MUMPS compiled with option -Dscotch
#  =================================================
# L D L^T Solver for general symmetric matrices
# Type of parallelism: Working host
#
#  ****** ANALYSIS STEP ********
#
#  Processing a graph of size:    371588
#  Average density of rows/columns =   15
#  Ordering based on SCOTCH
#  ELAPSED TIME SPENT IN SCOTCH reordering =      7.0557
#
# Leaving analysis phase with  ...
#  INFOG(1)                                       =               0
#  INFOG(2)                                       =               0
#  -- (20) Number of entries in factors (estim.)  =       119938903
#  --  (3) Real space for factors    (estimated)  =       125825883
#  --  (4) Integer space for factors (estimated)  =         3932766
#  --  (5) Maximum frontal size      (estimated)  =            3332
#  --  (6) Number of nodes in the tree            =           23405
#  -- (32) Type of analysis effectively used      =               1
#  --  (7) Ordering option effectively used       =               3
#  ICNTL (6) Maximum transversal option           =               0
#  ICNTL (7) Pivot order option                   =               3
#  ICNTL(12) Ordering symmetric indef. matrices   =               1
#  ICNTL(13) Parallelism/splitting of root node   =               0
#  ICNTL(14) Percentage of memory relaxation      =              20
#  ICNTL(15) Analysis by block effectively used   =               0
#  ICNTL(18) Distributed input matrix (on if >0)  =               0
#  ICNTL(32) Forward elimination during facto.    =               0
#  ICNTL(35) BLR activation                       =               0
#  ICNTL(48) Tree based multithreading (effective)=               1
#  ICNTL(58) Symbolic factorization option        =               2
#  Number of level 2 nodes                        =               0
#  Number of split nodes                          =               0
#  RINFOG(1) Operations during elimination (estim)= 1.246D+11
#
#  MEMORY ESTIMATIONS ...
#  Estimations with standard Full-Rank (FR) factorization:
#     Total space in MBytes, IC factorization      (INFOG(17)):            2754
#     Total space in MBytes,  OOC factorization    (INFOG(27)):            1441
#
#  Elapsed time in analysis driver=       7.2307
#
#
# ****** FACTORIZATION STEP ********
#
#  GLOBAL STATISTICS PRIOR NUMERICAL FACTORIZATION ...
#  Number of working processes                =               1
#  ICNTL(22) Out-of-core option               =               0
#  ICNTL(35) BLR activation (eff. choice)     =               0
#  ICNTL(37) BLR CB compression (eff. choice) =               0
#  ICNTL(49) Compact workarray S (end facto.) =               0
#  ICNTL(14) Memory relaxation                =              20
#  INFOG(3) Real space for factors (estimated)=       125825883
#  INFOG(4) Integer space for factors (estim.)=         3932766
#  Maximum frontal size (estimated)           =            3332
#  Number of nodes in the tree                =           23405
#  ICNTL(23) Memory allowed (value on host)   =               0
#            Sum over all procs               =               0
#  Memory provided by user, sum of LWK_USER   =               0
#  Effective threshold for pivoting, CNTL(1)  =      0.1000D-01
#
#  Statistics on the scaling phase
#  Elapsed time for scaling                   =      0.1196
#  Max difference from 1 after scaling the entries for ONE-NORM (option 7/8)   = 0.24D+00
#
#  Effective size of S     (based on INFO(39))=             51505490
#  Elapsed time to reformat/distribute matrix =      0.0681
#
#
#  Allocated buffers
#  ------------------
#  Size of reception buffer in bytes ...... =       140000
#  Size of async. emission buffer (bytes).. =       150019
#  Small emission buffer (bytes) .......... =           20
#
#  ** Memory allocated, total in Mbytes           (INFOG(19)):        2749
#  ** Memory effectively used, total in Mbytes    (INFOG(22)):        2611
#
#  Flops under L0 layer                       =   5.170D+10
#  Elapsed time under L0                      =     31.0038
#
#  Elapsed time for factorization                     =    128.2900
#
# Leaving factorization with ...
#  RINFOG (2) Operations in node assembly             = 1.889D+08
#  ------ (3) Operations in node elimination          = 1.246D+11
#  ICNTL  (8) Scaling effectively used                =               7
#  INFOG  (9) Real space for factors                  =       125825883
#  INFOG (10) Integer space for factors               =         3932766
#  INFOG (11) Maximum front size                      =            3332
#  INFOG (29) Number of entries in factors            =       119938903
#  INFOG (13) Number of delayed pivots                =               0
#  Number of 2x2 pivots in type 1 nodes               =               1
#  Number of 2x2 pivots in type 2 nodes               =               0
#  RINFOG(19) Smallest pivot WITH perturbed pivots    = 1.762D-07
#  RINFOG(20) Smallest pivot WITHOUT perturbed pivots = 1.762D-07
#  RINFOG(21) Largest pivot in absolute value         = 2.212D+00
#  INFOG (24) Effective value of ICNTL(12)            =               1
#  INFOG (14) Number of memory compress               =               0
#
#  Elapsed time in factorization driver               =    128.4875
#
#
#  ****** SOLVE & CHECK STEP ********
#
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           2
#   --- (20)                                     =           0
#   --- (21)                                     =           0
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           1
#
#  ERROR ANALYSIS
#
#  RESIDUAL IS ............ (INF-NORM)        = 1.58D-07
#                        .. (2-NORM)          = 4.57D-07
#  RINFOG(4):NORM OF input  Matrix  (INF-NORM)= 6.30D+01
#  RINFOG(5):NORM OF Computed SOLUT (INF-NORM)= 1.70D+11
#  RINFOG(6):SCALED RESIDUAL ...... (INF-NORM)= 1.48D-20
#  RINFOG(7):COMPONENTWISE SCALED RESIDUAL(W1)= 1.13D-15
#  ------(8):---------------------------- (W2)= 3.73D-23
#  ** Space in MBYTES used for solve                        :      2314
#
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.120339
#  Time in solution step (fwd/bwd)  =       3.523636
#   .. Time in forward (fwd) step   =          2.462893
#   .. Time in backward (bwd) step  =          1.060738
#  Time to gather solution(cent.sol)=       0.081688
#  Time for distributed solution    =       0.000000
#
#  Elapsed time in solve driver=       3.8689
#
# Entering ZMUMPS 5.7.3 with JOB =  -2
#       executing #MPI =      1 and #OMP =     20
# **********************************
# No error estimation!
# ***********************************************************
# Writing Volumetric Field Distribution in Entire Domain Now
#  Domain fields are written into in/GPR_model_anomaly_sphere.1.vtk
# Allocated variables were deallocated
# *************************************
# *************************************
# Modelling with elfe3D completed
# Output files are located in: /out
# *************************************
# *************************************
# CPU time to run elfe3D = 2892.456 seconds.
# Real time to run elfe3D =   195.360 seconds.
#
# ✓  done in 195.5s

# %% [markdown]
# ---
# ## 4 — Load results

# %%
result_txt = survey.io.output_dir / 'electric_fields_receiver_line.txt'
print('reading:', result_txt)

ef = ElfeLoader(
    filepath    = str(result_txt),
    label       = 'elfe3D layered sphere anomaly',
    num_endfire = 48,
).endfire()

print(f'r : {ef.r.min():.3f} – {ef.r.max():.3f} m   ({len(ef.r)} receivers)')
# Out:
# reading: f:\Projects\EMGeoInversion\elfe3D_GPR\elfe3D_GPR\out_anomaly_sphere\electric_fields_receiver_line.txt
# r : 0.100 – 1.000 m   (48 receivers)

# %% [markdown]
# ---
# ## 5 — Background reference

# %%
# Background reference = two-layer model without the anomaly
# Same CSV as the two-layered example — the anomaly response is the
# difference between this and the anomaly run.
ANALYTICAL_DIR = r'F:\Projects\EMGeoInversion\elfe3D_GPR\data\data_semi_analytical'

bg = AnalyticalLoader(
    os.path.join(ANALYTICAL_DIR, 'Exx_single_freq_4_9_100MHz_NR.csv'),
    label='Background (Evert)',
).endfire()

# %% [markdown]
# ---
# ## 6 — Anomaly vs background comparison

# %%
ReceiverLinePlot([bg, ef]).plot(suptitle="Endfire - Two-layered")

# %% [markdown]
# ## Anomaly response  (difference from background)

# %%
ReceiverLineErrorPlot([ef], reference=bg).plot(suptitle="Errors vs Semi-Analytical - Two-layered")

# %% [markdown]
# ## Combined (fields + anomaly response)

# %%
ReceiverLineCombined(ef, bg).plot(suptitle="Fields and Semi-Analytical - Two-layered")

# %% [markdown]
# ## Response distribution histogram

# %%
ErrorHistogramPlot([ef], reference=bg).plot(suptitle='Anomaly response distribution',)

# %% [markdown]
# ## Printed anomaly response summary

# %%
qty_names = ['Amplitude', 'Phase', 'Real', 'Imaginary']
print('Anomaly response (relative to two-layer background)\n')
for qi, name in enumerate(qty_names):
    err = field_error(bg, ef, qi)
    m, s, mx = error_stats(err)
    scale, unit = (100, '%') if qi != 1 else (1, 'rad')
    print(f'  {name:12s}:  mean={m*scale:.3f}{unit}  '
          f'std={s*scale:.3f}{unit}  max={mx*scale:.3f}{unit}')
# Out:
# Anomaly response (relative to two-layer background)
#
#   Amplitude   :  mean=3.034%  std=1.815%  max=5.503%
#   Phase       :  mean=-0.217rad  std=1.247rad  max=6.194rad
#   Real        :  mean=4.202%  std=4.509%  max=18.554%
#   Imaginary   :  mean=38.916%  std=145.813%  max=1016.744%
